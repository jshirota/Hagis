# %%
from attgeo import Mapper, Point
from dataclasses import dataclass

url = "https://sampleserver6.arcgisonline.com/arcgis/rest/services/USA/MapServer/0"

@dataclass(frozen=True)
class City:
    objectid: int
    areaname: str
    pop2000: int
    shape: Point

mapper = Mapper(url, City)

for city in mapper.read("pop2000 > 1000000", orderByFields="pop2000 DESC"):
    print(city.__dict__)
# Out:
# {'objectid': 2456, 'areaname': 'New York', 'pop2000': 8008278, 'shape': <attgeo.Point object at 0x000001ACD6AE88B0>}
# {'objectid': 376, 'areaname': 'Los Angeles', 'pop2000': 3694820, 'shape': <attgeo.Point object at 0x000001ACD6AE8CA0>}
# {'objectid': 1137, 'areaname': 'Chicago', 'pop2000': 2896016, 'shape': <attgeo.Point object at 0x000001ACD6AE8970>}
# {'objectid': 3114, 'areaname': 'Houston', 'pop2000': 1953631, 'shape': <attgeo.Point object at 0x000001ACD6AE8D30>}
# {'objectid': 2867, 'areaname': 'Philadelphia', 'pop2000': 1517550, 'shape': <attgeo.Point object at 0x000001ACD6AE8FA0>}
# {'objectid': 143, 'areaname': 'Phoenix', 'pop2000': 1321045, 'shape': <attgeo.Point object at 0x000001ACD6AE89A0>}
# {'objectid': 501, 'areaname': 'San Diego', 'pop2000': 1223400, 'shape': <attgeo.Point object at 0x000001ACD6AE8A30>}
# {'objectid': 3073, 'areaname': 'Dallas', 'pop2000': 1188580, 'shape': <attgeo.Point object at 0x000001ACD6AE8A90>}
# {'objectid': 3184, 'areaname': 'San Antonio', 'pop2000': 1144646, 'shape': <attgeo.Point object at 0x000001ACD4C37A30>}

# %%
from attgeo import Mapper, Polyline

url = "https://sampleserver6.arcgisonline.com/arcgis/rest/services/USA/MapServer/1"

class Highway:
    objectid: int
    type: str
    route: str
    shape: Polyline

mapper = Mapper(url, Highway)

for highway in mapper.read("route = 'Interstate  55'"):
    print(highway.__dict__)
# Out:
# {'objectid': 47, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD4C05430>}
# {'objectid': 63, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD6AE8DC0>}
# {'objectid': 197, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD6AE8DF0>}
# {'objectid': 198, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD4C0B7F0>}
# {'objectid': 240, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD4C0B280>}
# {'objectid': 247, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD6AF48B0>}
# {'objectid': 273, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD6AF40A0>}
# {'objectid': 279, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD6AF4070>}
# {'objectid': 319, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD6AF43A0>}
# {'objectid': 308, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD6AF4CA0>}
# {'objectid': 314, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD6AF4970>}
# {'objectid': 439, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD6AF4B20>}
# {'objectid': 441, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD6AF4B50>}
# {'objectid': 455, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD6AF4400>}
# {'objectid': 476, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD6AF4EE0>}
# {'objectid': 477, 'type': 'Multi-Lane Divided', 'route': 'Interstate  55', 'shape': <attgeo.Polyline object at 0x000001ACD6B340D0>}

# %%
from attgeo import Mapper, Polygon

url = "https://sampleserver6.arcgisonline.com/arcgis/rest/services/USA/MapServer/3"

class County:
    objectid: int
    name: str
    pop2000: int
    shape: Polygon

mapper = Mapper(url, County)

for county in mapper.read():
    print(county.__dict__)
# Out:
# {'objectid': 1, 'name': 'Lake of the Woods', 'pop2000': 4522, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BC70>}
# {'objectid': 2, 'name': 'Ferry', 'pop2000': 7260, 'shape': <attgeo.Polygon object at 0x000001ACD4C0B910>}
# {'objectid': 3, 'name': 'Stevens', 'pop2000': 40066, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4F70>}
# {'objectid': 4, 'name': 'Okanogan', 'pop2000': 39564, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4310>}
# {'objectid': 5, 'name': 'Pend Oreille', 'pop2000': 11732, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4D00>}
# {'objectid': 6, 'name': 'Boundary', 'pop2000': 9871, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4670>}
# {'objectid': 7, 'name': 'Lincoln', 'pop2000': 18837, 'shape': <attgeo.Polygon object at 0x000001ACD6AF48E0>}
# {'objectid': 8, 'name': 'Flathead', 'pop2000': 74471, 'shape': <attgeo.Polygon object at 0x000001ACD4B45BE0>}
# {'objectid': 9, 'name': 'Glacier', 'pop2000': 13247, 'shape': <attgeo.Polygon object at 0x000001ACD7280730>}
# {'objectid': 10, 'name': 'Toole', 'pop2000': 5267, 'shape': <attgeo.Polygon object at 0x000001ACD72807F0>}
# {'objectid': 11, 'name': 'Liberty', 'pop2000': 2158, 'shape': <attgeo.Polygon object at 0x000001ACD4B45EE0>}
# {'objectid': 12, 'name': 'Hill', 'pop2000': 16673, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4BB0>}
# {'objectid': 13, 'name': 'Sheridan', 'pop2000': 4105, 'shape': <attgeo.Polygon object at 0x000001ACD6AF40A0>}
# {'objectid': 14, 'name': 'Divide', 'pop2000': 2283, 'shape': <attgeo.Polygon object at 0x000001ACD6AF43A0>}
# {'objectid': 15, 'name': 'Burke', 'pop2000': 2242, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4280>}
# {'objectid': 16, 'name': 'Renville', 'pop2000': 2610, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BC70>}
# {'objectid': 17, 'name': 'Bottineau', 'pop2000': 7149, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BA60>}
# {'objectid': 18, 'name': 'Rolette', 'pop2000': 13674, 'shape': <attgeo.Polygon object at 0x000001ACD7280850>}
# {'objectid': 19, 'name': 'Towner', 'pop2000': 2876, 'shape': <attgeo.Polygon object at 0x000001ACD72806D0>}
# {'objectid': 20, 'name': 'Cavalier', 'pop2000': 4831, 'shape': <attgeo.Polygon object at 0x000001ACD7280910>}
# {'objectid': 21, 'name': 'Pembina', 'pop2000': 8585, 'shape': <attgeo.Polygon object at 0x000001ACD72809D0>}
# {'objectid': 22, 'name': 'Kittson', 'pop2000': 5285, 'shape': <attgeo.Polygon object at 0x000001ACD7280A90>}
# {'objectid': 23, 'name': 'Roseau', 'pop2000': 16338, 'shape': <attgeo.Polygon object at 0x000001ACD7280B50>}
# {'objectid': 24, 'name': 'Blaine', 'pop2000': 7009, 'shape': <attgeo.Polygon object at 0x000001ACD7280C10>}
# {'objectid': 25, 'name': 'Phillips', 'pop2000': 4601, 'shape': <attgeo.Polygon object at 0x000001ACD7280CD0>}
# {'objectid': 26, 'name': 'Valley', 'pop2000': 7675, 'shape': <attgeo.Polygon object at 0x000001ACD7280D90>}
# {'objectid': 27, 'name': 'Daniels', 'pop2000': 2017, 'shape': <attgeo.Polygon object at 0x000001ACD7280E50>}
# {'objectid': 28, 'name': 'Whatcom', 'pop2000': 166814, 'shape': <attgeo.Polygon object at 0x000001ACD7280F10>}
# {'objectid': 29, 'name': 'Bonner', 'pop2000': 36835, 'shape': <attgeo.Polygon object at 0x000001ACD7280FD0>}
# {'objectid': 30, 'name': 'Ward', 'pop2000': 58795, 'shape': <attgeo.Polygon object at 0x000001ACD72930D0>}
# {'objectid': 31, 'name': 'Koochiching', 'pop2000': 14355, 'shape': <attgeo.Polygon object at 0x000001ACD7293190>}
# {'objectid': 32, 'name': 'Skagit', 'pop2000': 102979, 'shape': <attgeo.Polygon object at 0x000001ACD7280FD0>}
# {'objectid': 33, 'name': 'Williams', 'pop2000': 19761, 'shape': <attgeo.Polygon object at 0x000001ACD7280D90>}
# {'objectid': 34, 'name': 'McHenry', 'pop2000': 5987, 'shape': <attgeo.Polygon object at 0x000001ACD7280CD0>}
# {'objectid': 148, 'name': 'Ashland', 'pop2000': 16866, 'shape': <attgeo.Polygon object at 0x000001ACD7280D30>}
# {'objectid': 35, 'name': 'St. Louis', 'pop2000': 200528, 'shape': <attgeo.Polygon object at 0x000001ACD7280FD0>}
# {'objectid': 36, 'name': 'San Juan', 'pop2000': 14077, 'shape': <attgeo.Polygon object at 0x000001ACD7280DC0>}
# {'objectid': 37, 'name': 'Roosevelt', 'pop2000': 10620, 'shape': <attgeo.Polygon object at 0x000001ACD7280FA0>}
# {'objectid': 38, 'name': 'Mountrail', 'pop2000': 6631, 'shape': <attgeo.Polygon object at 0x000001ACD7280D30>}
# {'objectid': 39, 'name': 'Marshall', 'pop2000': 10155, 'shape': <attgeo.Polygon object at 0x000001ACD7280CD0>}
# {'objectid': 40, 'name': 'Ramsey', 'pop2000': 12066, 'shape': <attgeo.Polygon object at 0x000001ACD7280C10>}
# {'objectid': 41, 'name': 'Walsh', 'pop2000': 12389, 'shape': <attgeo.Polygon object at 0x000001ACD7280D90>}
# {'objectid': 42, 'name': 'Beltrami', 'pop2000': 39650, 'shape': <attgeo.Polygon object at 0x000001ACD7280FA0>}
# {'objectid': 43, 'name': 'Pierce', 'pop2000': 4675, 'shape': <attgeo.Polygon object at 0x000001ACD7280DC0>}
# {'objectid': 44, 'name': 'Chelan', 'pop2000': 66616, 'shape': <attgeo.Polygon object at 0x000001ACD7280CD0>}
# {'objectid': 45, 'name': 'Pondera', 'pop2000': 6424, 'shape': <attgeo.Polygon object at 0x000001ACD7280AC0>}
# {'objectid': 46, 'name': 'Clallam', 'pop2000': 64525, 'shape': <attgeo.Polygon object at 0x000001ACD7280A00>}
# {'objectid': 47, 'name': 'Benson', 'pop2000': 6964, 'shape': <attgeo.Polygon object at 0x000001ACD7280940>}
# {'objectid': 48, 'name': 'Chouteau', 'pop2000': 5970, 'shape': <attgeo.Polygon object at 0x000001ACD72807C0>}
# {'objectid': 49, 'name': 'Snohomish', 'pop2000': 606024, 'shape': <attgeo.Polygon object at 0x000001ACD72807F0>}
# {'objectid': 50, 'name': 'Island', 'pop2000': 71558, 'shape': <attgeo.Polygon object at 0x000001ACD7280820>}
# {'objectid': 51, 'name': 'Sanders', 'pop2000': 10227, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BA60>}
# {'objectid': 52, 'name': 'Lake', 'pop2000': 11058, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BB50>}
# {'objectid': 53, 'name': 'Nelson', 'pop2000': 3715, 'shape': <attgeo.Polygon object at 0x000001ACD4C0B910>}
# {'objectid': 54, 'name': 'Grand Forks', 'pop2000': 66109, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4370>}
# {'objectid': 55, 'name': 'Polk', 'pop2000': 31369, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4EE0>}
# {'objectid': 56, 'name': 'Pennington', 'pop2000': 13584, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4C10>}
# {'objectid': 57, 'name': 'Douglas', 'pop2000': 32603, 'shape': <attgeo.Polygon object at 0x000001ACD6AF48E0>}
# {'objectid': 58, 'name': 'McKenzie', 'pop2000': 5737, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4A60>}
# {'objectid': 59, 'name': 'Jefferson', 'pop2000': 25953, 'shape': <attgeo.Polygon object at 0x000001ACD4B45D60>}
# {'objectid': 60, 'name': 'Richland', 'pop2000': 9667, 'shape': <attgeo.Polygon object at 0x000001ACD72931C0>}
# {'objectid': 61, 'name': 'Teton', 'pop2000': 6445, 'shape': <attgeo.Polygon object at 0x000001ACD7293130>}
# {'objectid': 62, 'name': 'McCone', 'pop2000': 1977, 'shape': <attgeo.Polygon object at 0x000001ACD7293250>}
# {'objectid': 63, 'name': 'Shoshone', 'pop2000': 13771, 'shape': <attgeo.Polygon object at 0x000001ACD7293310>}
# {'objectid': 64, 'name': 'Spokane', 'pop2000': 417939, 'shape': <attgeo.Polygon object at 0x000001ACD72933D0>}
# {'objectid': 223, 'name': 'Stevens', 'pop2000': 10053, 'shape': <attgeo.Polygon object at 0x000001ACD7293490>}
# {'objectid': 65, 'name': 'Lake', 'pop2000': 26507, 'shape': <attgeo.Polygon object at 0x000001ACD7293550>}
# {'objectid': 66, 'name': 'Clearwater', 'pop2000': 8423, 'shape': <attgeo.Polygon object at 0x000001ACD7293610>}
# {'objectid': 67, 'name': 'Kootenai', 'pop2000': 108685, 'shape': <attgeo.Polygon object at 0x000001ACD4B45FA0>}
# {'objectid': 68, 'name': 'Garfield', 'pop2000': 1279, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4970>}
# {'objectid': 69, 'name': 'Red Lake', 'pop2000': 4299, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4B20>}
# {'objectid': 70, 'name': 'Grant', 'pop2000': 74698, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4B50>}
# {'objectid': 71, 'name': 'Lincoln', 'pop2000': 10184, 'shape': <attgeo.Polygon object at 0x000001ACD6AF43A0>}
# {'objectid': 72, 'name': 'Lewis and Clark', 'pop2000': 55716, 'shape': <attgeo.Polygon object at 0x000001ACD4C0B790>}
# {'objectid': 73, 'name': 'Kitsap', 'pop2000': 231969, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BAC0>}
# {'objectid': 74, 'name': 'Itasca', 'pop2000': 43992, 'shape': <attgeo.Polygon object at 0x000001ACD7280790>}
# {'objectid': 75, 'name': 'Sheridan', 'pop2000': 1710, 'shape': <attgeo.Polygon object at 0x000001ACD72807F0>}
# {'objectid': 76, 'name': 'Wells', 'pop2000': 5102, 'shape': <attgeo.Polygon object at 0x000001ACD72808E0>}
# {'objectid': 77, 'name': 'McLean', 'pop2000': 9311, 'shape': <attgeo.Polygon object at 0x000001ACD72809A0>}
# {'objectid': 78, 'name': 'Eddy', 'pop2000': 2757, 'shape': <attgeo.Polygon object at 0x000001ACD7280A60>}
# {'objectid': 79, 'name': 'Dunn', 'pop2000': 3600, 'shape': <attgeo.Polygon object at 0x000001ACD7280B20>}
# {'objectid': 95, 'name': 'Norman', 'pop2000': 7442, 'shape': <attgeo.Polygon object at 0x000001ACD7280BE0>}
# {'objectid': 96, 'name': 'Mahnomen', 'pop2000': 5190, 'shape': <attgeo.Polygon object at 0x000001ACD7280CA0>}
# {'objectid': 502, 'name': 'Bremer', 'pop2000': 23325, 'shape': <attgeo.Polygon object at 0x000001ACD7280E50>}
# {'objectid': 80, 'name': 'Fergus', 'pop2000': 11893, 'shape': <attgeo.Polygon object at 0x000001ACD7280F40>}
# {'objectid': 81, 'name': 'Dawson', 'pop2000': 9059, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BAC0>}
# {'objectid': 82, 'name': 'King', 'pop2000': 1737034, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BB50>}
# {'objectid': 83, 'name': 'Cascade', 'pop2000': 80357, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4BB0>}
# {'objectid': 84, 'name': 'Griggs', 'pop2000': 2754, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4070>}
# {'objectid': 85, 'name': 'Steele', 'pop2000': 2258, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4A60>}
# {'objectid': 86, 'name': 'Traill', 'pop2000': 8477, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4AF0>}
# {'objectid': 87, 'name': 'Mason', 'pop2000': 49405, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4D00>}
# {'objectid': 88, 'name': 'Missoula', 'pop2000': 95802, 'shape': <attgeo.Polygon object at 0x000001ACD4B45EE0>}
# {'objectid': 89, 'name': 'Petroleum', 'pop2000': 493, 'shape': <attgeo.Polygon object at 0x000001ACD7280D60>}
# {'objectid': 90, 'name': 'Powell', 'pop2000': 7180, 'shape': <attgeo.Polygon object at 0x000001ACD7280EB0>}
# {'objectid': 91, 'name': 'Kittitas', 'pop2000': 33362, 'shape': <attgeo.Polygon object at 0x000001ACD7280DF0>}
# {'objectid': 92, 'name': 'Foster', 'pop2000': 3759, 'shape': <attgeo.Polygon object at 0x000001ACD7280B50>}
# {'objectid': 93, 'name': 'Mercer', 'pop2000': 8644, 'shape': <attgeo.Polygon object at 0x000001ACD7280A90>}
# {'objectid': 94, 'name': 'Grays Harbor', 'pop2000': 67194, 'shape': <attgeo.Polygon object at 0x000001ACD72809D0>}
# {'objectid': 149, 'name': 'Logan', 'pop2000': 2308, 'shape': <attgeo.Polygon object at 0x000001ACD7280910>}
# {'objectid': 97, 'name': 'Mineral', 'pop2000': 3884, 'shape': <attgeo.Polygon object at 0x000001ACD72806D0>}
# {'objectid': 98, 'name': 'Cass', 'pop2000': 27150, 'shape': <attgeo.Polygon object at 0x000001ACD7280850>}
# {'objectid': 99, 'name': 'Aroostook', 'pop2000': 73938, 'shape': <attgeo.Polygon object at 0x000001ACD7280760>}
# {'objectid': 100, 'name': 'Judith Basin', 'pop2000': 2329, 'shape': <attgeo.Polygon object at 0x000001ACD7280B80>}
# {'objectid': 101, 'name': 'Hubbard', 'pop2000': 18376, 'shape': <attgeo.Polygon object at 0x000001ACD7294070>}
# {'objectid': 102, 'name': 'Benewah', 'pop2000': 9171, 'shape': <attgeo.Polygon object at 0x000001ACD7294130>}
# {'objectid': 103, 'name': 'Wibaux', 'pop2000': 1068, 'shape': <attgeo.Polygon object at 0x000001ACD72941F0>}
# {'objectid': 104, 'name': 'Golden Valley', 'pop2000': 1924, 'shape': <attgeo.Polygon object at 0x000001ACD72942B0>}
# {'objectid': 105, 'name': 'Billings', 'pop2000': 888, 'shape': <attgeo.Polygon object at 0x000001ACD7294370>}
# {'objectid': 106, 'name': 'Stutsman', 'pop2000': 21908, 'shape': <attgeo.Polygon object at 0x000001ACD7294430>}
# {'objectid': 107, 'name': 'Kidder', 'pop2000': 2753, 'shape': <attgeo.Polygon object at 0x000001ACD72944F0>}
# {'objectid': 108, 'name': 'Burleigh', 'pop2000': 69416, 'shape': <attgeo.Polygon object at 0x000001ACD72945B0>}
# {'objectid': 109, 'name': 'Pierce', 'pop2000': 700820, 'shape': <attgeo.Polygon object at 0x000001ACD7294670>}
# {'objectid': 110, 'name': 'Oliver', 'pop2000': 2065, 'shape': <attgeo.Polygon object at 0x000001ACD7294730>}
# {'objectid': 111, 'name': 'Adams', 'pop2000': 16428, 'shape': <attgeo.Polygon object at 0x000001ACD72947F0>}
# {'objectid': 112, 'name': 'Whitman', 'pop2000': 40740, 'shape': <attgeo.Polygon object at 0x000001ACD72948B0>}
# {'objectid': 113, 'name': 'Barnes', 'pop2000': 11775, 'shape': <attgeo.Polygon object at 0x000001ACD7294970>}
# {'objectid': 132, 'name': 'Pacific', 'pop2000': 20984, 'shape': <attgeo.Polygon object at 0x000001ACD7294A30>}
# {'objectid': 114, 'name': 'Cass', 'pop2000': 123138, 'shape': <attgeo.Polygon object at 0x000001ACD7294AF0>}
# {'objectid': 115, 'name': 'Prairie', 'pop2000': 1199, 'shape': <attgeo.Polygon object at 0x000001ACD7294BB0>}
# {'objectid': 116, 'name': 'Becker', 'pop2000': 30000, 'shape': <attgeo.Polygon object at 0x000001ACD7294C70>}
# {'objectid': 117, 'name': 'Clay', 'pop2000': 51229, 'shape': <attgeo.Polygon object at 0x000001ACD7294D30>}
# {'objectid': 118, 'name': 'Thurston', 'pop2000': 207355, 'shape': <attgeo.Polygon object at 0x000001ACD7294DF0>}
# {'objectid': 119, 'name': 'Latah', 'pop2000': 34935, 'shape': <attgeo.Polygon object at 0x000001ACD7294EB0>}
# {'objectid': 120, 'name': 'Meagher', 'pop2000': 1932, 'shape': <attgeo.Polygon object at 0x000001ACD7294F70>}
# {'objectid': 121, 'name': 'Yakima', 'pop2000': 222581, 'shape': <attgeo.Polygon object at 0x000001ACD7299070>}
# {'objectid': 122, 'name': 'Aitkin', 'pop2000': 15301, 'shape': <attgeo.Polygon object at 0x000001ACD7299130>}
# {'objectid': 123, 'name': 'Stark', 'pop2000': 22636, 'shape': <attgeo.Polygon object at 0x000001ACD72991F0>}
# {'objectid': 124, 'name': 'Morton', 'pop2000': 25303, 'shape': <attgeo.Polygon object at 0x000001ACD72992B0>}
# {'objectid': 125, 'name': 'Bayfield', 'pop2000': 15013, 'shape': <attgeo.Polygon object at 0x000001ACD7299370>}
# {'objectid': 126, 'name': 'Clearwater', 'pop2000': 8930, 'shape': <attgeo.Polygon object at 0x000001ACD7299430>}
# {'objectid': 127, 'name': 'Custer', 'pop2000': 11696, 'shape': <attgeo.Polygon object at 0x000001ACD72994F0>}
# {'objectid': 128, 'name': 'Rosebud', 'pop2000': 9383, 'shape': <attgeo.Polygon object at 0x000001ACD72995B0>}
# {'objectid': 129, 'name': 'Granite', 'pop2000': 2830, 'shape': <attgeo.Polygon object at 0x000001ACD7299670>}
# {'objectid': 130, 'name': 'Wadena', 'pop2000': 13713, 'shape': <attgeo.Polygon object at 0x000001ACD7299730>}
# {'objectid': 131, 'name': 'Crow Wing', 'pop2000': 55099, 'shape': <attgeo.Polygon object at 0x000001ACD72997F0>}
# {'objectid': 133, 'name': 'Lewis', 'pop2000': 68600, 'shape': <attgeo.Polygon object at 0x000001ACD72998B0>}
# {'objectid': 134, 'name': 'Broadwater', 'pop2000': 4385, 'shape': <attgeo.Polygon object at 0x000001ACD7299970>}
# {'objectid': 135, 'name': 'Carlton', 'pop2000': 31671, 'shape': <attgeo.Polygon object at 0x000001ACD7299A30>}
# {'objectid': 136, 'name': 'Golden Valley', 'pop2000': 1042, 'shape': <attgeo.Polygon object at 0x000001ACD7299AF0>}
# {'objectid': 137, 'name': 'Douglas', 'pop2000': 43287, 'shape': <attgeo.Polygon object at 0x000001ACD7299BB0>}
# {'objectid': 138, 'name': 'Musselshell', 'pop2000': 4497, 'shape': <attgeo.Polygon object at 0x000001ACD7299C70>}
# {'objectid': 139, 'name': 'Wheatland', 'pop2000': 2259, 'shape': <attgeo.Polygon object at 0x000001ACD7299D30>}
# {'objectid': 140, 'name': 'Franklin', 'pop2000': 49347, 'shape': <attgeo.Polygon object at 0x000001ACD7299DF0>}
# {'objectid': 141, 'name': 'Benton', 'pop2000': 142475, 'shape': <attgeo.Polygon object at 0x000001ACD7299EB0>}
# {'objectid': 142, 'name': 'Grant', 'pop2000': 2841, 'shape': <attgeo.Polygon object at 0x000001ACD7299F70>}
# {'objectid': 143, 'name': 'Otter Tail', 'pop2000': 57159, 'shape': <attgeo.Polygon object at 0x000001ACD729D070>}
# {'objectid': 144, 'name': 'Garfield', 'pop2000': 2397, 'shape': <attgeo.Polygon object at 0x000001ACD729D130>}
# {'objectid': 145, 'name': 'Fallon', 'pop2000': 2837, 'shape': <attgeo.Polygon object at 0x000001ACD729D1F0>}
# {'objectid': 146, 'name': 'Idaho', 'pop2000': 15511, 'shape': <attgeo.Polygon object at 0x000001ACD729D2B0>}
# {'objectid': 147, 'name': 'Ravalli', 'pop2000': 36070, 'shape': <attgeo.Polygon object at 0x000001ACD729D370>}
# {'objectid': 150, 'name': 'Emmons', 'pop2000': 4331, 'shape': <attgeo.Polygon object at 0x000001ACD729D430>}
# {'objectid': 151, 'name': 'LaMoure', 'pop2000': 4701, 'shape': <attgeo.Polygon object at 0x000001ACD729D4F0>}
# {'objectid': 152, 'name': 'Slope', 'pop2000': 767, 'shape': <attgeo.Polygon object at 0x000001ACD729D5B0>}
# {'objectid': 153, 'name': 'Hettinger', 'pop2000': 2715, 'shape': <attgeo.Polygon object at 0x000001ACD729D670>}
# {'objectid': 154, 'name': 'Ransom', 'pop2000': 5890, 'shape': <attgeo.Polygon object at 0x000001ACD729D730>}
# {'objectid': 155, 'name': 'Richland', 'pop2000': 17998, 'shape': <attgeo.Polygon object at 0x000001ACD729D7F0>}
# {'objectid': 156, 'name': 'Wilkin', 'pop2000': 7138, 'shape': <attgeo.Polygon object at 0x000001ACD729D8B0>}
# {'objectid': 157, 'name': 'Nez Perce', 'pop2000': 37410, 'shape': <attgeo.Polygon object at 0x000001ACD729D970>}
# {'objectid': 158, 'name': 'Columbia', 'pop2000': 4064, 'shape': <attgeo.Polygon object at 0x000001ACD729DA30>}
# {'objectid': 159, 'name': 'Walla Walla', 'pop2000': 55180, 'shape': <attgeo.Polygon object at 0x000001ACD729DAF0>}
# {'objectid': 160, 'name': 'Iron', 'pop2000': 6861, 'shape': <attgeo.Polygon object at 0x000001ACD729DBB0>}
# {'objectid': 161, 'name': 'Somerset', 'pop2000': 50888, 'shape': <attgeo.Polygon object at 0x000001ACD729DC70>}
# {'objectid': 162, 'name': 'Piscataquis', 'pop2000': 17235, 'shape': <attgeo.Polygon object at 0x000001ACD729DD30>}
# {'objectid': 163, 'name': 'Jefferson', 'pop2000': 10049, 'shape': <attgeo.Polygon object at 0x000001ACD729DDF0>}
# {'objectid': 164, 'name': 'Yellowstone', 'pop2000': 129352, 'shape': <attgeo.Polygon object at 0x000001ACD729DEB0>}
# {'objectid': 165, 'name': 'Treasure', 'pop2000': 861, 'shape': <attgeo.Polygon object at 0x000001ACD729DF70>}
# {'objectid': 186, 'name': 'Park', 'pop2000': 15694, 'shape': <attgeo.Polygon object at 0x000001ACD6B61070>}
# {'objectid': 166, 'name': 'Lewis', 'pop2000': 3747, 'shape': <attgeo.Polygon object at 0x000001ACD6B61130>}
# {'objectid': 167, 'name': 'Asotin', 'pop2000': 20551, 'shape': <attgeo.Polygon object at 0x000001ACD6B611F0>}
# {'objectid': 168, 'name': 'Sioux', 'pop2000': 4044, 'shape': <attgeo.Polygon object at 0x000001ACD6B612B0>}
# {'objectid': 169, 'name': 'Pine', 'pop2000': 26530, 'shape': <attgeo.Polygon object at 0x000001ACD6B61370>}
# {'objectid': 170, 'name': 'Penobscot', 'pop2000': 144919, 'shape': <attgeo.Polygon object at 0x000001ACD6B61430>}
# {'objectid': 171, 'name': 'Skamania', 'pop2000': 9872, 'shape': <attgeo.Polygon object at 0x000001ACD6B614F0>}
# {'objectid': 172, 'name': 'Cowlitz', 'pop2000': 92948, 'shape': <attgeo.Polygon object at 0x000001ACD6B615B0>}
# {'objectid': 173, 'name': 'Wahkiakum', 'pop2000': 3824, 'shape': <attgeo.Polygon object at 0x000001ACD6B61670>}
# {'objectid': 174, 'name': 'Todd', 'pop2000': 24426, 'shape': <attgeo.Polygon object at 0x000001ACD6B61730>}
# {'objectid': 175, 'name': 'Morrison', 'pop2000': 31712, 'shape': <attgeo.Polygon object at 0x000001ACD6B617F0>}
# {'objectid': 176, 'name': 'McIntosh', 'pop2000': 3390, 'shape': <attgeo.Polygon object at 0x000001ACD6B618B0>}
# {'objectid': 177, 'name': 'Dickey', 'pop2000': 5757, 'shape': <attgeo.Polygon object at 0x000001ACD6B61970>}
# {'objectid': 178, 'name': 'Sargent', 'pop2000': 4366, 'shape': <attgeo.Polygon object at 0x000001ACD6B61A30>}
# {'objectid': 179, 'name': 'Bowman', 'pop2000': 3242, 'shape': <attgeo.Polygon object at 0x000001ACD6B61AF0>}
# {'objectid': 180, 'name': 'Adams', 'pop2000': 2593, 'shape': <attgeo.Polygon object at 0x000001ACD6B61BB0>}
# {'objectid': 181, 'name': 'Deer Lodge', 'pop2000': 9417, 'shape': <attgeo.Polygon object at 0x000001ACD6B61C70>}
# {'objectid': 182, 'name': 'Mille Lacs', 'pop2000': 22330, 'shape': <attgeo.Polygon object at 0x000001ACD7280B80>}
# {'objectid': 183, 'name': 'Clatsop', 'pop2000': 35630, 'shape': <attgeo.Polygon object at 0x000001ACD72807F0>}
# {'objectid': 184, 'name': 'Sweet Grass', 'pop2000': 3609, 'shape': <attgeo.Polygon object at 0x000001ACD72808E0>}
# {'objectid': 185, 'name': 'Gallatin', 'pop2000': 67831, 'shape': <attgeo.Polygon object at 0x000001ACD72809A0>}
# {'objectid': 224, 'name': 'Isanti', 'pop2000': 31287, 'shape': <attgeo.Polygon object at 0x000001ACD7280A60>}
# {'objectid': 187, 'name': 'Columbia', 'pop2000': 43560, 'shape': <attgeo.Polygon object at 0x000001ACD7280B20>}
# {'objectid': 188, 'name': 'Silver Bow', 'pop2000': 34606, 'shape': <attgeo.Polygon object at 0x000001ACD7280BE0>}
# {'objectid': 189, 'name': 'Washburn', 'pop2000': 16036, 'shape': <attgeo.Polygon object at 0x000001ACD7280CA0>}
# {'objectid': 190, 'name': 'Sawyer', 'pop2000': 16196, 'shape': <attgeo.Polygon object at 0x000001ACD7280C10>}
# {'objectid': 191, 'name': 'Burnett', 'pop2000': 15674, 'shape': <attgeo.Polygon object at 0x000001ACD7280C40>}
# {'objectid': 192, 'name': 'Kanabec', 'pop2000': 14996, 'shape': <attgeo.Polygon object at 0x000001ACD7280F40>}
# {'objectid': 193, 'name': 'Carter', 'pop2000': 1360, 'shape': <attgeo.Polygon object at 0x000001ACD4B45D60>}
# {'objectid': 194, 'name': 'Stillwater', 'pop2000': 8195, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4EE0>}
# {'objectid': 195, 'name': 'Grant', 'pop2000': 6289, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4370>}
# {'objectid': 196, 'name': 'Douglas', 'pop2000': 32821, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4280>}
# {'objectid': 197, 'name': 'Clark', 'pop2000': 345238, 'shape': <attgeo.Polygon object at 0x000001ACD6AF40A0>}
# {'objectid': 198, 'name': 'Klickitat', 'pop2000': 19161, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4B50>}
# {'objectid': 199, 'name': 'Big Horn', 'pop2000': 12671, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BAC0>}
# {'objectid': 200, 'name': 'Traverse', 'pop2000': 4134, 'shape': <attgeo.Polygon object at 0x000001ACD6AF40A0>}
# {'objectid': 201, 'name': 'Umatilla', 'pop2000': 70548, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4670>}
# {'objectid': 202, 'name': 'Wallowa', 'pop2000': 7226, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4D00>}
# {'objectid': 203, 'name': 'Price', 'pop2000': 15822, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4970>}
# {'objectid': 204, 'name': 'Campbell', 'pop2000': 1782, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4370>}
# {'objectid': 205, 'name': 'Harding', 'pop2000': 1353, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4BB0>}
# {'objectid': 206, 'name': 'McPherson', 'pop2000': 2904, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4310>}
# {'objectid': 207, 'name': 'Perkins', 'pop2000': 3363, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4D00>}
# {'objectid': 208, 'name': 'Corson', 'pop2000': 4181, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4EE0>}
# {'objectid': 209, 'name': 'Brown', 'pop2000': 35460, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4670>}
# {'objectid': 210, 'name': 'Beaverhead', 'pop2000': 9202, 'shape': <attgeo.Polygon object at 0x000001ACD4B45D60>}
# {'objectid': 211, 'name': 'Marshall', 'pop2000': 4576, 'shape': <attgeo.Polygon object at 0x000001ACD7280F40>}
# {'objectid': 212, 'name': 'Roberts', 'pop2000': 10016, 'shape': <attgeo.Polygon object at 0x000001ACD7280FD0>}
# {'objectid': 213, 'name': 'Morrow', 'pop2000': 10995, 'shape': <attgeo.Polygon object at 0x000001ACD7280D60>}
# {'objectid': 214, 'name': 'Union', 'pop2000': 24530, 'shape': <attgeo.Polygon object at 0x000001ACD7280EB0>}
# {'objectid': 215, 'name': 'Madison', 'pop2000': 6851, 'shape': <attgeo.Polygon object at 0x000001ACD7280DF0>}
# {'objectid': 216, 'name': 'Benton', 'pop2000': 34226, 'shape': <attgeo.Polygon object at 0x000001ACD7280B50>}
# {'objectid': 217, 'name': 'Gilliam', 'pop2000': 1915, 'shape': <attgeo.Polygon object at 0x000001ACD7280A90>}
# {'objectid': 218, 'name': 'Powder River', 'pop2000': 1858, 'shape': <attgeo.Polygon object at 0x000001ACD72809D0>}
# {'objectid': 219, 'name': 'Stearns', 'pop2000': 133166, 'shape': <attgeo.Polygon object at 0x000001ACD7280910>}
# {'objectid': 220, 'name': 'Tillamook', 'pop2000': 24262, 'shape': <attgeo.Polygon object at 0x000001ACD72806D0>}
# {'objectid': 221, 'name': 'Washington', 'pop2000': 445342, 'shape': <attgeo.Polygon object at 0x000001ACD7280760>}
# {'objectid': 222, 'name': 'Pope', 'pop2000': 11236, 'shape': <attgeo.Polygon object at 0x000001ACD4B45BE0>}
# {'objectid': 619, 'name': 'Iowa', 'pop2000': 15671, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4B50>}
# {'objectid': 225, 'name': 'Chisago', 'pop2000': 41101, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4070>}
# {'objectid': 226, 'name': 'Sherman', 'pop2000': 1934, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4370>}
# {'objectid': 227, 'name': 'Polk', 'pop2000': 41319, 'shape': <attgeo.Polygon object at 0x000001ACD6AF40A0>}
# {'objectid': 228, 'name': 'Multnomah', 'pop2000': 660486, 'shape': <attgeo.Polygon object at 0x000001ACD7280850>}
# {'objectid': 229, 'name': 'Hood River', 'pop2000': 20411, 'shape': <attgeo.Polygon object at 0x000001ACD7280F70>}
# {'objectid': 230, 'name': 'Wasco', 'pop2000': 23791, 'shape': <attgeo.Polygon object at 0x000001ACD7280D30>}
# {'objectid': 231, 'name': 'Lemhi', 'pop2000': 7806, 'shape': <attgeo.Polygon object at 0x000001ACD72807C0>}
# {'objectid': 232, 'name': 'Washington', 'pop2000': 33941, 'shape': <attgeo.Polygon object at 0x000001ACD7280940>}
# {'objectid': 233, 'name': 'Franklin', 'pop2000': 29467, 'shape': <attgeo.Polygon object at 0x000001ACD7280A00>}
# {'objectid': 234, 'name': 'Barron', 'pop2000': 44963, 'shape': <attgeo.Polygon object at 0x000001ACD7280AC0>}
# {'objectid': 235, 'name': 'Rusk', 'pop2000': 15347, 'shape': <attgeo.Polygon object at 0x000001ACD7280CD0>}
# {'objectid': 236, 'name': 'Carbon', 'pop2000': 9552, 'shape': <attgeo.Polygon object at 0x000001ACD7280DC0>}
# {'objectid': 237, 'name': 'Walworth', 'pop2000': 5974, 'shape': <attgeo.Polygon object at 0x000001ACD7280FA0>}
# {'objectid': 238, 'name': 'Edmunds', 'pop2000': 4367, 'shape': <attgeo.Polygon object at 0x000001ACD72806D0>}
# {'objectid': 239, 'name': 'Day', 'pop2000': 6267, 'shape': <attgeo.Polygon object at 0x000001ACD4C0B790>}
# {'objectid': 299, 'name': 'Pierce', 'pop2000': 36804, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BBB0>}
# {'objectid': 240, 'name': 'Big Stone', 'pop2000': 5820, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BA60>}
# {'objectid': 241, 'name': 'Sherburne', 'pop2000': 64417, 'shape': <attgeo.Polygon object at 0x000001ACD72980D0>}
# {'objectid': 242, 'name': 'Ziebach', 'pop2000': 2519, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BAC0>}
# {'objectid': 243, 'name': 'Dewey', 'pop2000': 5972, 'shape': <attgeo.Polygon object at 0x000001ACD72806D0>}
# {'objectid': 244, 'name': 'Clackamas', 'pop2000': 338391, 'shape': <attgeo.Polygon object at 0x000001ACD7280E50>}
# {'objectid': 245, 'name': 'Wright', 'pop2000': 89986, 'shape': <attgeo.Polygon object at 0x000001ACD7280C10>}
# {'objectid': 246, 'name': 'Yamhill', 'pop2000': 84992, 'shape': <attgeo.Polygon object at 0x000001ACD7280CA0>}
# {'objectid': 247, 'name': 'Anoka', 'pop2000': 298084, 'shape': <attgeo.Polygon object at 0x000001ACD7280BE0>}
# {'objectid': 248, 'name': 'Kandiyohi', 'pop2000': 41203, 'shape': <attgeo.Polygon object at 0x000001ACD7280B20>}
# {'objectid': 249, 'name': 'Swift', 'pop2000': 11956, 'shape': <attgeo.Polygon object at 0x000001ACD7280A60>}
# {'objectid': 250, 'name': 'Taylor', 'pop2000': 19680, 'shape': <attgeo.Polygon object at 0x000001ACD72809A0>}
# {'objectid': 251, 'name': 'Oxford', 'pop2000': 54755, 'shape': <attgeo.Polygon object at 0x000001ACD72808E0>}
# {'objectid': 252, 'name': 'Grant', 'pop2000': 7847, 'shape': <attgeo.Polygon object at 0x000001ACD7280700>}
# {'objectid': 253, 'name': 'Meeker', 'pop2000': 22644, 'shape': <attgeo.Polygon object at 0x000001ACD7280B80>}
# {'objectid': 254, 'name': 'Coos', 'pop2000': 33111, 'shape': <attgeo.Polygon object at 0x000001ACD7280760>}
# {'objectid': 255, 'name': 'Washington', 'pop2000': 201130, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4310>}
# {'objectid': 256, 'name': 'Chippewa', 'pop2000': 55195, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4D00>}
# {'objectid': 275, 'name': 'Meade', 'pop2000': 24253, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4A60>}
# {'objectid': 276, 'name': 'Lincoln', 'pop2000': 44479, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4D30>}
# {'objectid': 277, 'name': 'Clark', 'pop2000': 33557, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4AF0>}
# {'objectid': 257, 'name': 'Marion', 'pop2000': 284834, 'shape': <attgeo.Polygon object at 0x000001ACD4B45FA0>}
# {'objectid': 258, 'name': 'Lac Qui Parle', 'pop2000': 8067, 'shape': <attgeo.Polygon object at 0x000001ACD7294FD0>}
# {'objectid': 259, 'name': 'Adams', 'pop2000': 3476, 'shape': <attgeo.Polygon object at 0x000001ACD7294DF0>}
# {'objectid': 260, 'name': 'Potter', 'pop2000': 2693, 'shape': <attgeo.Polygon object at 0x000001ACD4B45D60>}
# {'objectid': 261, 'name': 'Faulk', 'pop2000': 2640, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4C10>}
# {'objectid': 262, 'name': 'Hennepin', 'pop2000': 1116200, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4280>}
# {'objectid': 263, 'name': 'Spink', 'pop2000': 7454, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4BB0>}
# {'objectid': 264, 'name': 'St. Croix', 'pop2000': 63155, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4370>}
# {'objectid': 265, 'name': 'Dunn', 'pop2000': 39858, 'shape': <attgeo.Polygon object at 0x000001ACD7280820>}
# {'objectid': 266, 'name': 'Butte', 'pop2000': 9094, 'shape': <attgeo.Polygon object at 0x000001ACD7280970>}
# {'objectid': 267, 'name': 'Valley', 'pop2000': 7651, 'shape': <attgeo.Polygon object at 0x000001ACD7280A30>}
# {'objectid': 268, 'name': 'Clark', 'pop2000': 4143, 'shape': <attgeo.Polygon object at 0x000001ACD7280AF0>}
# {'objectid': 269, 'name': 'Codington', 'pop2000': 25897, 'shape': <attgeo.Polygon object at 0x000001ACD7280BB0>}
# {'objectid': 270, 'name': 'Chippewa', 'pop2000': 13088, 'shape': <attgeo.Polygon object at 0x000001ACD7280C70>}
# {'objectid': 271, 'name': 'Ramsey', 'pop2000': 511035, 'shape': <attgeo.Polygon object at 0x000001ACD7280E80>}
# {'objectid': 272, 'name': 'Baker', 'pop2000': 16741, 'shape': <attgeo.Polygon object at 0x000001ACD7280F10>}
# {'objectid': 273, 'name': 'Polk', 'pop2000': 62380, 'shape': <attgeo.Polygon object at 0x000001ACD7280D90>}
# {'objectid': 274, 'name': 'Wheeler', 'pop2000': 1547, 'shape': <attgeo.Polygon object at 0x000001ACD7280C40>}
# {'objectid': 296, 'name': 'Hyde', 'pop2000': 1671, 'shape': <attgeo.Polygon object at 0x000001ACD7280E20>}
# {'objectid': 278, 'name': 'Essex', 'pop2000': 6459, 'shape': <attgeo.Polygon object at 0x000001ACD4C0B850>}
# {'objectid': 279, 'name': 'Grand Isle', 'pop2000': 6901, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BC70>}
# {'objectid': 280, 'name': 'Franklin', 'pop2000': 45417, 'shape': <attgeo.Polygon object at 0x000001ACD4C0B910>}
# {'objectid': 281, 'name': 'Orleans', 'pop2000': 26277, 'shape': <attgeo.Polygon object at 0x000001ACD72980D0>}
# {'objectid': 282, 'name': 'Clinton', 'pop2000': 79894, 'shape': <attgeo.Polygon object at 0x000001ACD7298190>}
# {'objectid': 283, 'name': 'Park', 'pop2000': 25786, 'shape': <attgeo.Polygon object at 0x000001ACD7298250>}
# {'objectid': 284, 'name': 'Crook', 'pop2000': 5887, 'shape': <attgeo.Polygon object at 0x000001ACD7298310>}
# {'objectid': 285, 'name': 'Big Horn', 'pop2000': 11461, 'shape': <attgeo.Polygon object at 0x000001ACD72983D0>}
# {'objectid': 286, 'name': 'Campbell', 'pop2000': 33698, 'shape': <attgeo.Polygon object at 0x000001ACD7298490>}
# {'objectid': 287, 'name': 'Sheridan', 'pop2000': 26560, 'shape': <attgeo.Polygon object at 0x000001ACD7298550>}
# {'objectid': 288, 'name': 'Franklin', 'pop2000': 51134, 'shape': <attgeo.Polygon object at 0x000001ACD7298610>}
# {'objectid': 289, 'name': 'Grant', 'pop2000': 7935, 'shape': <attgeo.Polygon object at 0x000001ACD72986D0>}
# {'objectid': 290, 'name': 'McLeod', 'pop2000': 34898, 'shape': <attgeo.Polygon object at 0x000001ACD7298790>}
# {'objectid': 291, 'name': 'Carver', 'pop2000': 70205, 'shape': <attgeo.Polygon object at 0x000001ACD7298850>}
# {'objectid': 292, 'name': 'Deuel', 'pop2000': 4498, 'shape': <attgeo.Polygon object at 0x000001ACD7298910>}
# {'objectid': 293, 'name': 'Dakota', 'pop2000': 355904, 'shape': <attgeo.Polygon object at 0x000001ACD72989D0>}
# {'objectid': 294, 'name': 'Yellow Medicine', 'pop2000': 11080, 'shape': <attgeo.Polygon object at 0x000001ACD7298A90>}
# {'objectid': 295, 'name': 'Sully', 'pop2000': 1556, 'shape': <attgeo.Polygon object at 0x000001ACD7298B50>}
# {'objectid': 297, 'name': 'Hand', 'pop2000': 3741, 'shape': <attgeo.Polygon object at 0x000001ACD7298C10>}
# {'objectid': 298, 'name': 'Renville', 'pop2000': 17154, 'shape': <attgeo.Polygon object at 0x000001ACD7298CD0>}
# {'objectid': 300, 'name': 'Custer', 'pop2000': 4342, 'shape': <attgeo.Polygon object at 0x000001ACD7298D90>}
# {'objectid': 301, 'name': 'Eau Claire', 'pop2000': 93142, 'shape': <attgeo.Polygon object at 0x000001ACD7298E50>}
# {'objectid': 302, 'name': 'Washington', 'pop2000': 9977, 'shape': <attgeo.Polygon object at 0x000001ACD7298F10>}
# {'objectid': 303, 'name': 'Jefferson', 'pop2000': 19009, 'shape': <attgeo.Polygon object at 0x000001ACD7298FD0>}
# {'objectid': 304, 'name': 'Scott', 'pop2000': 89498, 'shape': <attgeo.Polygon object at 0x000001ACD6B630D0>}
# {'objectid': 305, 'name': 'Hamlin', 'pop2000': 5540, 'shape': <attgeo.Polygon object at 0x000001ACD6B63190>}
# {'objectid': 306, 'name': 'Lamoille', 'pop2000': 23233, 'shape': <attgeo.Polygon object at 0x000001ACD6B63250>}
# {'objectid': 307, 'name': 'Linn', 'pop2000': 103069, 'shape': <attgeo.Polygon object at 0x000001ACD6B63310>}
# {'objectid': 308, 'name': 'Stanley', 'pop2000': 2772, 'shape': <attgeo.Polygon object at 0x000001ACD6B633D0>}
# {'objectid': 309, 'name': 'Caledonia', 'pop2000': 29702, 'shape': <attgeo.Polygon object at 0x000001ACD6B63490>}
# {'objectid': 310, 'name': 'Waldo', 'pop2000': 36280, 'shape': <attgeo.Polygon object at 0x000001ACD6B63550>}
# {'objectid': 311, 'name': 'Haakon', 'pop2000': 2196, 'shape': <attgeo.Polygon object at 0x000001ACD6B63610>}
# {'objectid': 312, 'name': 'Fremont', 'pop2000': 11819, 'shape': <attgeo.Polygon object at 0x000001ACD6B636D0>}
# {'objectid': 313, 'name': 'Sibley', 'pop2000': 15356, 'shape': <attgeo.Polygon object at 0x000001ACD6B63790>}
# {'objectid': 314, 'name': 'Chittenden', 'pop2000': 146571, 'shape': <attgeo.Polygon object at 0x000001ACD6B63850>}
# {'objectid': 335, 'name': 'Rice', 'pop2000': 56665, 'shape': <attgeo.Polygon object at 0x000001ACD6B63910>}
# {'objectid': 315, 'name': 'Kennebec', 'pop2000': 117114, 'shape': <attgeo.Polygon object at 0x000001ACD6B639D0>}
# {'objectid': 316, 'name': 'Goodhue', 'pop2000': 44127, 'shape': <attgeo.Polygon object at 0x000001ACD6B63A90>}
# {'objectid': 317, 'name': 'Benton', 'pop2000': 78153, 'shape': <attgeo.Polygon object at 0x000001ACD6B63B50>}
# {'objectid': 318, 'name': 'Redwood', 'pop2000': 16815, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BC70>}
# {'objectid': 319, 'name': 'Wood', 'pop2000': 75555, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BBB0>}
# {'objectid': 320, 'name': 'Pepin', 'pop2000': 7213, 'shape': <attgeo.Polygon object at 0x000001ACD7280790>}
# {'objectid': 321, 'name': 'Teton', 'pop2000': 18251, 'shape': <attgeo.Polygon object at 0x000001ACD7280D90>}
# {'objectid': 322, 'name': 'Beadle', 'pop2000': 17023, 'shape': <attgeo.Polygon object at 0x000001ACD7280F10>}
# {'objectid': 323, 'name': 'Lyon', 'pop2000': 25425, 'shape': <attgeo.Polygon object at 0x000001ACD7280E80>}
# {'objectid': 324, 'name': 'Lincoln', 'pop2000': 6429, 'shape': <attgeo.Polygon object at 0x000001ACD7280C70>}
# {'objectid': 325, 'name': 'Lawrence', 'pop2000': 21802, 'shape': <attgeo.Polygon object at 0x000001ACD7280BB0>}
# {'objectid': 326, 'name': 'Buffalo', 'pop2000': 13804, 'shape': <attgeo.Polygon object at 0x000001ACD7280AF0>}
# {'objectid': 327, 'name': 'Trempealeau', 'pop2000': 27010, 'shape': <attgeo.Polygon object at 0x000001ACD7280A30>}
# {'objectid': 328, 'name': 'Jackson', 'pop2000': 19100, 'shape': <attgeo.Polygon object at 0x000001ACD7280970>}
# {'objectid': 329, 'name': 'Clark', 'pop2000': 1022, 'shape': <attgeo.Polygon object at 0x000001ACD7280820>}
# {'objectid': 330, 'name': 'Crook', 'pop2000': 19182, 'shape': <attgeo.Polygon object at 0x000001ACD7280760>}
# {'objectid': 331, 'name': 'Johnson', 'pop2000': 7075, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4370>}
# {'objectid': 332, 'name': 'Hughes', 'pop2000': 16481, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4280>}
# {'objectid': 369, 'name': 'Steele', 'pop2000': 33680, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4C10>}
# {'objectid': 333, 'name': 'Essex', 'pop2000': 38851, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4D30>}
# {'objectid': 334, 'name': 'Le Sueur', 'pop2000': 25426, 'shape': <attgeo.Polygon object at 0x000001ACD6AF43A0>}
# {'objectid': 2536, 'name': 'Howard', 'pop2000': 33627, 'shape': <attgeo.Polygon object at 0x000001ACD4B45D60>}
# {'objectid': 336, 'name': 'Kingsbury', 'pop2000': 5815, 'shape': <attgeo.Polygon object at 0x000001ACD7294070>}
# {'objectid': 337, 'name': 'Brookings', 'pop2000': 28220, 'shape': <attgeo.Polygon object at 0x000001ACD7294130>}
# {'objectid': 338, 'name': 'Pennington', 'pop2000': 88565, 'shape': <attgeo.Polygon object at 0x000001ACD72941F0>}
# {'objectid': 339, 'name': 'Gem', 'pop2000': 15181, 'shape': <attgeo.Polygon object at 0x000001ACD72942B0>}
# {'objectid': 340, 'name': 'Brown', 'pop2000': 26911, 'shape': <attgeo.Polygon object at 0x000001ACD7294370>}
# {'objectid': 341, 'name': 'Washington', 'pop2000': 58039, 'shape': <attgeo.Polygon object at 0x000001ACD7294430>}
# {'objectid': 342, 'name': 'Androscoggin', 'pop2000': 103793, 'shape': <attgeo.Polygon object at 0x000001ACD4B45D60>}
# {'objectid': 343, 'name': 'Nicollet', 'pop2000': 29771, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4970>}
# {'objectid': 344, 'name': 'Wabasha', 'pop2000': 21610, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4F70>}
# {'objectid': 345, 'name': 'Malheur', 'pop2000': 31615, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4BB0>}
# {'objectid': 346, 'name': 'Hancock', 'pop2000': 51791, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4B50>}
# {'objectid': 347, 'name': 'Grafton', 'pop2000': 81743, 'shape': <attgeo.Polygon object at 0x000001ACD7280760>}
# {'objectid': 348, 'name': 'Deschutes', 'pop2000': 115367, 'shape': <attgeo.Polygon object at 0x000001ACD7280A90>}
# {'objectid': 349, 'name': 'Knox', 'pop2000': 39618, 'shape': <attgeo.Polygon object at 0x000001ACD7280B50>}
# {'objectid': 370, 'name': 'Olmsted', 'pop2000': 124277, 'shape': <attgeo.Polygon object at 0x000001ACD4B45BE0>}
# {'objectid': 371, 'name': 'Miner', 'pop2000': 2884, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4B50>}
# {'objectid': 350, 'name': 'Boise', 'pop2000': 6670, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4F70>}
# {'objectid': 351, 'name': 'Lincoln', 'pop2000': 33616, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4970>}
# {'objectid': 352, 'name': 'Addison', 'pop2000': 35974, 'shape': <attgeo.Polygon object at 0x000001ACD4B45FA0>}
# {'objectid': 353, 'name': 'Carroll', 'pop2000': 43666, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4B50>}
# {'objectid': 354, 'name': 'Lane', 'pop2000': 322959, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4370>}
# {'objectid': 355, 'name': 'Blue Earth', 'pop2000': 55941, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4A60>}
# {'objectid': 356, 'name': 'Juneau', 'pop2000': 24316, 'shape': <attgeo.Polygon object at 0x000001ACD6AF48E0>}
# {'objectid': 357, 'name': 'Butte', 'pop2000': 2899, 'shape': <attgeo.Polygon object at 0x000001ACD4B45BE0>}
# {'objectid': 358, 'name': 'Lyman', 'pop2000': 3895, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4F70>}
# {'objectid': 359, 'name': 'Orange', 'pop2000': 28226, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4AF0>}
# {'objectid': 360, 'name': 'Waseca', 'pop2000': 19526, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4970>}
# {'objectid': 361, 'name': 'Buffalo', 'pop2000': 2032, 'shape': <attgeo.Polygon object at 0x000001ACD4B45FA0>}
# {'objectid': 362, 'name': 'Jerauld', 'pop2000': 2295, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4BB0>}
# {'objectid': 363, 'name': 'Moody', 'pop2000': 6595, 'shape': <attgeo.Polygon object at 0x000001ACD6AF40A0>}
# {'objectid': 364, 'name': 'Pipestone', 'pop2000': 9895, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4B20>}
# {'objectid': 365, 'name': 'Dodge', 'pop2000': 17731, 'shape': <attgeo.Polygon object at 0x000001ACD6AF43A0>}
# {'objectid': 366, 'name': 'Sanborn', 'pop2000': 2675, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4A60>}
# {'objectid': 367, 'name': 'Murray', 'pop2000': 9165, 'shape': <attgeo.Polygon object at 0x000001ACD7280D00>}
# {'objectid': 368, 'name': 'Cottonwood', 'pop2000': 12167, 'shape': <attgeo.Polygon object at 0x000001ACD7280970>}
# {'objectid': 372, 'name': 'Lake', 'pop2000': 11276, 'shape': <attgeo.Polygon object at 0x000001ACD7280820>}
# {'objectid': 373, 'name': 'Winona', 'pop2000': 49985, 'shape': <attgeo.Polygon object at 0x000001ACD7280AF0>}
# {'objectid': 374, 'name': 'Weston', 'pop2000': 6644, 'shape': <attgeo.Polygon object at 0x000001ACD7280BB0>}
# {'objectid': 375, 'name': 'Jones', 'pop2000': 1193, 'shape': <attgeo.Polygon object at 0x000001ACD7280C70>}
# {'objectid': 376, 'name': 'Cumberland', 'pop2000': 265612, 'shape': <attgeo.Polygon object at 0x000001ACD7280E80>}
# {'objectid': 377, 'name': 'Washakie', 'pop2000': 8289, 'shape': <attgeo.Polygon object at 0x000001ACD7280F10>}
# {'objectid': 378, 'name': 'Monroe', 'pop2000': 40899, 'shape': <attgeo.Polygon object at 0x000001ACD7280D90>}
# {'objectid': 379, 'name': 'Payette', 'pop2000': 20578, 'shape': <attgeo.Polygon object at 0x000001ACD7280790>}
# {'objectid': 380, 'name': 'Hamilton', 'pop2000': 5379, 'shape': <attgeo.Polygon object at 0x000001ACD7280E20>}
# {'objectid': 381, 'name': 'Watonwan', 'pop2000': 11876, 'shape': <attgeo.Polygon object at 0x000001ACD7280790>}
# {'objectid': 382, 'name': 'Herkimer', 'pop2000': 64427, 'shape': <attgeo.Polygon object at 0x000001ACD7280CA0>}
# {'objectid': 383, 'name': 'La Crosse', 'pop2000': 107120, 'shape': <attgeo.Polygon object at 0x000001ACD7280BE0>}
# {'objectid': 384, 'name': 'Elmore', 'pop2000': 29130, 'shape': <attgeo.Polygon object at 0x000001ACD7280B20>}
# {'objectid': 385, 'name': 'Hot Springs', 'pop2000': 4882, 'shape': <attgeo.Polygon object at 0x000001ACD7280A60>}
# {'objectid': 386, 'name': 'Jefferson', 'pop2000': 19155, 'shape': <attgeo.Polygon object at 0x000001ACD72809A0>}
# {'objectid': 387, 'name': 'Harney', 'pop2000': 7609, 'shape': <attgeo.Polygon object at 0x000001ACD7280910>}
# {'objectid': 388, 'name': 'Sagadahoc', 'pop2000': 35214, 'shape': <attgeo.Polygon object at 0x000001ACD7280760>}
# {'objectid': 389, 'name': 'Fremont', 'pop2000': 35804, 'shape': <attgeo.Polygon object at 0x000001ACD72808E0>}
# {'objectid': 390, 'name': 'Jackson', 'pop2000': 2930, 'shape': <attgeo.Polygon object at 0x000001ACD7280A30>}
# {'objectid': 391, 'name': 'Blaine', 'pop2000': 18991, 'shape': <attgeo.Polygon object at 0x000001ACD7280B50>}
# {'objectid': 392, 'name': 'Teton', 'pop2000': 5999, 'shape': <attgeo.Polygon object at 0x000001ACD4B45BE0>}
# {'objectid': 393, 'name': 'Windsor', 'pop2000': 57418, 'shape': <attgeo.Polygon object at 0x000001ACD6AF43A0>}
# {'objectid': 394, 'name': 'Douglas', 'pop2000': 100399, 'shape': <attgeo.Polygon object at 0x000001ACD6AF48E0>}
# {'objectid': 395, 'name': 'Aurora', 'pop2000': 3058, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4670>}
# {'objectid': 396, 'name': 'Brule', 'pop2000': 5364, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4D30>}
# {'objectid': 397, 'name': 'Madison', 'pop2000': 27467, 'shape': <attgeo.Polygon object at 0x000001ACD6AF4310>}
# {'objectid': 398, 'name': 'Canyon', 'pop2000': 131441, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BC70>}
# {'objectid': 399, 'name': 'Mellette', 'pop2000': 2083, 'shape': <attgeo.Polygon object at 0x000001ACD4C0B310>}
# {'objectid': 400, 'name': 'Camas', 'pop2000': 991, 'shape': <attgeo.Polygon object at 0x000001ACD6B61070>}
# {'objectid': 401, 'name': 'Custer', 'pop2000': 7275, 'shape': <attgeo.Polygon object at 0x000001ACD6B61130>}
# {'objectid': 402, 'name': 'Rutland', 'pop2000': 63400, 'shape': <attgeo.Polygon object at 0x000001ACD6B611F0>}
# {'objectid': 403, 'name': 'Faribault', 'pop2000': 16181, 'shape': <attgeo.Polygon object at 0x000001ACD6B612B0>}
# {'objectid': 404, 'name': 'Minnehaha', 'pop2000': 148281, 'shape': <attgeo.Polygon object at 0x000001ACD6B61370>}
# {'objectid': 405, 'name': 'Rock', 'pop2000': 9721, 'shape': <attgeo.Polygon object at 0x000001ACD6B61430>}
# {'objectid': 406, 'name': 'Freeborn', 'pop2000': 32584, 'shape': <attgeo.Polygon object at 0x000001ACD6B614F0>}
# {'objectid': 407, 'name': 'Nobles', 'pop2000': 20832, 'shape': <attgeo.Polygon object at 0x000001ACD6B615B0>}
# {'objectid': 408, 'name': 'Jackson', 'pop2000': 11268, 'shape': <attgeo.Polygon object at 0x000001ACD6B61670>}
# {'objectid': 409, 'name': 'Martin', 'pop2000': 21802, 'shape': <attgeo.Polygon object at 0x000001ACD6B61730>}
# {'objectid': 410, 'name': 'Houston', 'pop2000': 19718, 'shape': <attgeo.Polygon object at 0x000001ACD6B617F0>}
# {'objectid': 411, 'name': 'Mower', 'pop2000': 38603, 'shape': <attgeo.Polygon object at 0x000001ACD6B618B0>}
# {'objectid': 412, 'name': 'Fillmore', 'pop2000': 21122, 'shape': <attgeo.Polygon object at 0x000001ACD6B61970>}
# {'objectid': 413, 'name': 'Davison', 'pop2000': 18741, 'shape': <attgeo.Polygon object at 0x000001ACD6B61A30>}
# {'objectid': 414, 'name': 'Hanson', 'pop2000': 3139, 'shape': <attgeo.Polygon object at 0x000001ACD6B61AF0>}
# {'objectid': 415, 'name': 'McCook', 'pop2000': 5832, 'shape': <attgeo.Polygon object at 0x000001ACD6B61BB0>}
# {'objectid': 416, 'name': 'York', 'pop2000': 186742, 'shape': <attgeo.Polygon object at 0x000001ACD6B61C70>}
# {'objectid': 417, 'name': 'Washington', 'pop2000': 61042, 'shape': <attgeo.Polygon object at 0x000001ACD6B61D30>}
# {'objectid': 418, 'name': 'Ada', 'pop2000': 300904, 'shape': <attgeo.Polygon object at 0x000001ACD6B61DF0>}
# {'objectid': 419, 'name': 'Warren', 'pop2000': 63303, 'shape': <attgeo.Polygon object at 0x000001ACD6B61EB0>}
# {'objectid': 420, 'name': 'Tripp', 'pop2000': 6430, 'shape': <attgeo.Polygon object at 0x000001ACD6B61F70>}
# {'objectid': 421, 'name': 'Belknap', 'pop2000': 56325, 'shape': <attgeo.Polygon object at 0x000001ACD6B68070>}
# {'objectid': 422, 'name': 'Vernon', 'pop2000': 28056, 'shape': <attgeo.Polygon object at 0x000001ACD6B68130>}
# {'objectid': 423, 'name': 'Shannon', 'pop2000': 12466, 'shape': <attgeo.Polygon object at 0x000001ACD6B681F0>}
# {'objectid': 424, 'name': 'Owyhee', 'pop2000': 10644, 'shape': <attgeo.Polygon object at 0x000001ACD6B682B0>}
# {'objectid': 425, 'name': 'Bonneville', 'pop2000': 82522, 'shape': <attgeo.Polygon object at 0x000001ACD6B68370>}
# {'objectid': 426, 'name': 'Bingham', 'pop2000': 41735, 'shape': <attgeo.Polygon object at 0x000001ACD6B68430>}
# {'objectid': 427, 'name': 'Klamath', 'pop2000': 63775, 'shape': <attgeo.Polygon object at 0x000001ACD6B684F0>}
# {'objectid': 428, 'name': 'Lake', 'pop2000': 7422, 'shape': <attgeo.Polygon object at 0x000001ACD6B685B0>}
# {'objectid': 429, 'name': 'Coos', 'pop2000': 62779, 'shape': <attgeo.Polygon object at 0x000001ACD6B68670>}
# {'objectid': 430, 'name': 'Merrimack', 'pop2000': 136225, 'shape': <attgeo.Polygon object at 0x000001ACD6B68730>}
# {'objectid': 431, 'name': 'Sullivan', 'pop2000': 40458, 'shape': <attgeo.Polygon object at 0x000001ACD6B687F0>}
# ...
# {'objectid': 3001, 'name': 'Oceana', 'pop2000': 26873, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BA60>}
# {'objectid': 3002, 'name': 'Isabella', 'pop2000': 63351, 'shape': <attgeo.Polygon object at 0x000001ACD6B685E0>}
# {'objectid': 3003, 'name': 'Newaygo', 'pop2000': 47874, 'shape': <attgeo.Polygon object at 0x000001ACD6B68DC0>}
# {'objectid': 3004, 'name': 'Mecosta', 'pop2000': 40553, 'shape': <attgeo.Polygon object at 0x000001ACD6B68190>}
# {'objectid': 3005, 'name': 'Tuscola', 'pop2000': 58266, 'shape': <attgeo.Polygon object at 0x000001ACD6B68460>}
# {'objectid': 3006, 'name': 'Oswego', 'pop2000': 122377, 'shape': <attgeo.Polygon object at 0x000001ACD6B68F70>}
# {'objectid': 3007, 'name': 'Sanilac', 'pop2000': 44547, 'shape': <attgeo.Polygon object at 0x000001ACD6B682B0>}
# {'objectid': 3008, 'name': 'Columbia', 'pop2000': 52468, 'shape': <attgeo.Polygon object at 0x000001ACD6B686D0>}
# {'objectid': 3009, 'name': 'Sauk', 'pop2000': 55225, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC0A0>}
# {'objectid': 3010, 'name': 'Dodge', 'pop2000': 85897, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC1F0>}
# {'objectid': 3011, 'name': 'Oneida', 'pop2000': 235469, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC280>}
# {'objectid': 3012, 'name': 'Saginaw', 'pop2000': 210039, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC490>}
# {'objectid': 3013, 'name': 'Washington', 'pop2000': 117493, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC4F0>}
# {'objectid': 3014, 'name': 'Ozaukee', 'pop2000': 82317, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC550>}
# {'objectid': 3015, 'name': 'Muskegon', 'pop2000': 170200, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC6D0>}
# {'objectid': 3016, 'name': 'Montcalm', 'pop2000': 61266, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC730>}
# {'objectid': 3017, 'name': 'Gratiot', 'pop2000': 42285, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC790>}
# {'objectid': 3018, 'name': 'Cayuga', 'pop2000': 81963, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC910>}
# {'objectid': 3019, 'name': 'Niagara', 'pop2000': 219846, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC970>}
# {'objectid': 3020, 'name': 'Orleans', 'pop2000': 44171, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC9D0>}
# {'objectid': 3021, 'name': 'Monroe', 'pop2000': 735343, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BC70>}
# {'objectid': 3022, 'name': 'Wayne', 'pop2000': 93765, 'shape': <attgeo.Polygon object at 0x000001ACD6B683D0>}
# {'objectid': 3023, 'name': 'Lapeer', 'pop2000': 87904, 'shape': <attgeo.Polygon object at 0x000001ACD6B68A00>}
# {'objectid': 3024, 'name': 'Kent', 'pop2000': 574335, 'shape': <attgeo.Polygon object at 0x000001ACD6B68D60>}
# {'objectid': 3025, 'name': 'Dane', 'pop2000': 426526, 'shape': <attgeo.Polygon object at 0x000001ACD6B68D00>}
# {'objectid': 3026, 'name': 'Onondaga', 'pop2000': 458336, 'shape': <attgeo.Polygon object at 0x000001ACD6B683A0>}
# {'objectid': 3027, 'name': 'Genesee', 'pop2000': 436141, 'shape': <attgeo.Polygon object at 0x000001ACD6B680D0>}
# {'objectid': 3028, 'name': 'Ottawa', 'pop2000': 238314, 'shape': <attgeo.Polygon object at 0x000001ACD4C0B790>}
# {'objectid': 3029, 'name': 'Jefferson', 'pop2000': 74021, 'shape': <attgeo.Polygon object at 0x000001ACD6B68D00>}
# {'objectid': 3030, 'name': 'Waukesha', 'pop2000': 360767, 'shape': <attgeo.Polygon object at 0x000001ACD6B68D60>}
# {'objectid': 3031, 'name': 'Milwaukee', 'pop2000': 940164, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BB50>}
# {'objectid': 3032, 'name': 'Madison', 'pop2000': 69441, 'shape': <attgeo.Polygon object at 0x000001ACD6B68310>}
# {'objectid': 3033, 'name': 'St. Clair', 'pop2000': 164235, 'shape': <attgeo.Polygon object at 0x000001ACD6B685E0>}
# {'objectid': 3034, 'name': 'Shiawassee', 'pop2000': 71687, 'shape': <attgeo.Polygon object at 0x000001ACD6B68A00>}
# {'objectid': 3035, 'name': 'Genesee', 'pop2000': 60370, 'shape': <attgeo.Polygon object at 0x000001ACD4C0B850>}
# {'objectid': 3036, 'name': 'Ionia', 'pop2000': 61518, 'shape': <attgeo.Polygon object at 0x000001ACD6B68310>}
# {'objectid': 3037, 'name': 'Clinton', 'pop2000': 64753, 'shape': <attgeo.Polygon object at 0x000001ACD6B68DC0>}
# {'objectid': 3038, 'name': 'Erie', 'pop2000': 950265, 'shape': <attgeo.Polygon object at 0x000001ACD6B68640>}
# {'objectid': 3039, 'name': 'Ontario', 'pop2000': 100224, 'shape': <attgeo.Polygon object at 0x000001ACD6B683D0>}
# {'objectid': 3040, 'name': 'Seneca', 'pop2000': 33342, 'shape': <attgeo.Polygon object at 0x000001ACD6B682B0>}
# {'objectid': 3041, 'name': 'Livingston', 'pop2000': 64328, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BC70>}
# {'objectid': 3042, 'name': 'Macomb', 'pop2000': 788149, 'shape': <attgeo.Polygon object at 0x000001ACD6B686D0>}
# {'objectid': 3043, 'name': 'Oakland', 'pop2000': 1194156, 'shape': <attgeo.Polygon object at 0x000001ACD6B68640>}
# {'objectid': 3044, 'name': 'Wyoming', 'pop2000': 43424, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BA60>}
# {'objectid': 3045, 'name': 'Green', 'pop2000': 33647, 'shape': <attgeo.Polygon object at 0x000001ACD6B68640>}
# {'objectid': 3046, 'name': 'Rock', 'pop2000': 152307, 'shape': <attgeo.Polygon object at 0x000001ACD6B68460>}
# {'objectid': 3047, 'name': 'Walworth', 'pop2000': 93759, 'shape': <attgeo.Polygon object at 0x000001ACD6B68790>}
# {'objectid': 3048, 'name': 'Racine', 'pop2000': 188831, 'shape': <attgeo.Polygon object at 0x000001ACD6B68850>}
# {'objectid': 3049, 'name': 'Cortland', 'pop2000': 48599, 'shape': <attgeo.Polygon object at 0x000001ACD6B680D0>}
# {'objectid': 3050, 'name': 'Livingston', 'pop2000': 156951, 'shape': <attgeo.Polygon object at 0x000001ACD6B68A00>}
# {'objectid': 3051, 'name': 'Ingham', 'pop2000': 279320, 'shape': <attgeo.Polygon object at 0x000001ACD6B683A0>}
# {'objectid': 3052, 'name': 'Allegan', 'pop2000': 105665, 'shape': <attgeo.Polygon object at 0x000001ACD4C0B790>}
# {'objectid': 3053, 'name': 'Eaton', 'pop2000': 103655, 'shape': <attgeo.Polygon object at 0x000001ACD6B680D0>}
# {'objectid': 3054, 'name': 'Barry', 'pop2000': 56755, 'shape': <attgeo.Polygon object at 0x000001ACD6B68850>}
# {'objectid': 3055, 'name': 'Yates', 'pop2000': 24621, 'shape': <attgeo.Polygon object at 0x000001ACD6B68790>}
# {'objectid': 3056, 'name': 'Chenango', 'pop2000': 51401, 'shape': <attgeo.Polygon object at 0x000001ACD6B68460>}
# {'objectid': 3057, 'name': 'Kenosha', 'pop2000': 149577, 'shape': <attgeo.Polygon object at 0x000001ACD6B68640>}
# {'objectid': 3058, 'name': 'Tompkins', 'pop2000': 96501, 'shape': <attgeo.Polygon object at 0x000001ACD6B68CA0>}
# {'objectid': 3059, 'name': 'Steuben', 'pop2000': 98726, 'shape': <attgeo.Polygon object at 0x000001ACD6BBCA90>}
# {'objectid': 3060, 'name': 'Chautauqua', 'pop2000': 139750, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC8E0>}
# {'objectid': 3061, 'name': 'Schuyler', 'pop2000': 19224, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC8B0>}
# {'objectid': 3062, 'name': 'Cattaraugus', 'pop2000': 83955, 'shape': <attgeo.Polygon object at 0x000001ACD6B68A00>}
# {'objectid': 3063, 'name': 'Allegany', 'pop2000': 49927, 'shape': <attgeo.Polygon object at 0x000001ACD6B68790>}
# {'objectid': 3064, 'name': 'Stephenson', 'pop2000': 48979, 'shape': <attgeo.Polygon object at 0x000001ACD6B68850>}
# {'objectid': 3065, 'name': 'Winnebago', 'pop2000': 278418, 'shape': <attgeo.Polygon object at 0x000001ACD6B680D0>}
# {'objectid': 3066, 'name': 'McHenry', 'pop2000': 260077, 'shape': <attgeo.Polygon object at 0x000001ACD6B68190>}
# {'objectid': 3067, 'name': 'Boone', 'pop2000': 41786, 'shape': <attgeo.Polygon object at 0x000001ACD6B68100>}
# {'objectid': 3068, 'name': 'Lake', 'pop2000': 644356, 'shape': <attgeo.Polygon object at 0x000001ACD4C0B790>}
# {'objectid': 3069, 'name': 'Wayne', 'pop2000': 2061162, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC9A0>}
# {'objectid': 3070, 'name': 'Washtenaw', 'pop2000': 322895, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC9D0>}
# {'objectid': 3071, 'name': 'Jackson', 'pop2000': 158422, 'shape': <attgeo.Polygon object at 0x000001ACD6BBCA30>}
# {'objectid': 3072, 'name': 'Kalamazoo', 'pop2000': 238603, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BC70>}
# {'objectid': 3073, 'name': 'Calhoun', 'pop2000': 137985, 'shape': <attgeo.Polygon object at 0x000001ACD4C0B790>}
# {'objectid': 3074, 'name': 'Van Buren', 'pop2000': 76263, 'shape': <attgeo.Polygon object at 0x000001ACD6B68CA0>}
# {'objectid': 3075, 'name': 'Broome', 'pop2000': 200536, 'shape': <attgeo.Polygon object at 0x000001ACD6B683A0>}
# {'objectid': 3076, 'name': 'Tioga', 'pop2000': 51784, 'shape': <attgeo.Polygon object at 0x000001ACD6B68D60>}
# {'objectid': 3077, 'name': 'Chemung', 'pop2000': 91070, 'shape': <attgeo.Polygon object at 0x000001ACD6B68F70>}
# {'objectid': 3078, 'name': 'Erie', 'pop2000': 280843, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BB50>}
# {'objectid': 3079, 'name': 'Berrien', 'pop2000': 162453, 'shape': <attgeo.Polygon object at 0x000001ACD6B68640>}
# {'objectid': 3080, 'name': 'Ogle', 'pop2000': 51032, 'shape': <attgeo.Polygon object at 0x000001ACD6B68550>}
# {'objectid': 3081, 'name': 'Carroll', 'pop2000': 16674, 'shape': <attgeo.Polygon object at 0x000001ACD6B68D00>}
# {'objectid': 3082, 'name': 'Cook', 'pop2000': 5376741, 'shape': <attgeo.Polygon object at 0x000001ACD6B68310>}
# {'objectid': 3083, 'name': 'Kane', 'pop2000': 404119, 'shape': <attgeo.Polygon object at 0x000001ACD6B68250>}
# {'objectid': 3084, 'name': 'DeKalb', 'pop2000': 88969, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BB50>}
# {'objectid': 3085, 'name': 'Monroe', 'pop2000': 145945, 'shape': <attgeo.Polygon object at 0x000001ACD6B685B0>}
# {'objectid': 3086, 'name': 'Lenawee', 'pop2000': 98890, 'shape': <attgeo.Polygon object at 0x000001ACD6B683A0>}
# {'objectid': 3087, 'name': 'Hillsdale', 'pop2000': 46527, 'shape': <attgeo.Polygon object at 0x000001ACD6B68D60>}
# {'objectid': 3088, 'name': 'Branch', 'pop2000': 45787, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BC70>}
# {'objectid': 3089, 'name': 'St. Joseph', 'pop2000': 62422, 'shape': <attgeo.Polygon object at 0x000001ACD6B68190>}
# {'objectid': 3090, 'name': 'Cass', 'pop2000': 51104, 'shape': <attgeo.Polygon object at 0x000001ACD4C0B790>}
# {'objectid': 3091, 'name': 'Bradford', 'pop2000': 62761, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BA60>}
# {'objectid': 3092, 'name': 'Tioga', 'pop2000': 41373, 'shape': <attgeo.Polygon object at 0x000001ACD6B682B0>}
# {'objectid': 3093, 'name': 'Warren', 'pop2000': 43863, 'shape': <attgeo.Polygon object at 0x000001ACD6B685B0>}
# {'objectid': 3094, 'name': 'Susquehanna', 'pop2000': 42238, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BB50>}
# {'objectid': 3095, 'name': 'McKean', 'pop2000': 45936, 'shape': <attgeo.Polygon object at 0x000001ACD6B68A00>}
# {'objectid': 3096, 'name': 'Potter', 'pop2000': 18080, 'shape': <attgeo.Polygon object at 0x000001ACD6B68190>}
# {'objectid': 3097, 'name': 'DuPage', 'pop2000': 904161, 'shape': <attgeo.Polygon object at 0x000001ACD6B68250>}
# {'objectid': 3098, 'name': 'Ashtabula', 'pop2000': 102728, 'shape': <attgeo.Polygon object at 0x000001ACD6B68BE0>}
# {'objectid': 3099, 'name': 'Whiteside', 'pop2000': 60653, 'shape': <attgeo.Polygon object at 0x000001ACD6B68850>}
# {'objectid': 3100, 'name': 'Lee', 'pop2000': 36062, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BC70>}
# {'objectid': 3101, 'name': 'Crawford', 'pop2000': 90366, 'shape': <attgeo.Polygon object at 0x000001ACD6B68250>}
# {'objectid': 3102, 'name': 'Lake', 'pop2000': 227511, 'shape': <attgeo.Polygon object at 0x000001ACD6B68190>}
# {'objectid': 3103, 'name': 'LaPorte', 'pop2000': 110106, 'shape': <attgeo.Polygon object at 0x000001ACD6B68A00>}
# {'objectid': 3104, 'name': 'St. Joseph', 'pop2000': 265559, 'shape': <attgeo.Polygon object at 0x000001ACD6B685B0>}
# {'objectid': 3105, 'name': 'Elkhart', 'pop2000': 182791, 'shape': <attgeo.Polygon object at 0x000001ACD6B68BE0>}
# {'objectid': 3106, 'name': 'Lagrange', 'pop2000': 34909, 'shape': <attgeo.Polygon object at 0x000001ACD6B686D0>}
# {'objectid': 3107, 'name': 'Steuben', 'pop2000': 33214, 'shape': <attgeo.Polygon object at 0x000001ACD6B68BE0>}
# {'objectid': 3108, 'name': 'North Slope', 'pop2000': 7385, 'shape': <attgeo.Polygon object at 0x000001ACD6B68CA0>}
# {'objectid': 3109, 'name': 'Northwest Arctic', 'pop2000': 7208, 'shape': <attgeo.Polygon object at 0x000001ACD6B685E0>}
# {'objectid': 3110, 'name': 'Fairbanks North Star', 'pop2000': 82840, 'shape': <attgeo.Polygon object at 0x000001ACD6B68790>}
# {'objectid': 3111, 'name': 'Bristol Bay', 'pop2000': 1258, 'shape': <attgeo.Polygon object at 0x000001ACD6B68550>}
# {'objectid': 3112, 'name': 'Nome', 'pop2000': 9196, 'shape': <attgeo.Polygon object at 0x000001ACD6B68850>}
# {'objectid': 3113, 'name': 'Matanuska-Susitna', 'pop2000': 59322, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BA60>}
# {'objectid': 3114, 'name': 'Wade Hampton', 'pop2000': 7028, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BB50>}
# {'objectid': 3115, 'name': 'Bethel', 'pop2000': 16006, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC940>}
# {'objectid': 3116, 'name': 'Anchorage', 'pop2000': 260283, 'shape': <attgeo.Polygon object at 0x000001ACD6BBCAC0>}
# {'objectid': 3117, 'name': 'Kenai Peninsula', 'pop2000': 49691, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC9D0>}
# {'objectid': 3118, 'name': 'Dillingham', 'pop2000': 4922, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC820>}
# {'objectid': 3119, 'name': 'Lake and Peninsula', 'pop2000': 1823, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC7C0>}
# {'objectid': 3120, 'name': 'Haines', 'pop2000': 2392, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC760>}
# {'objectid': 3121, 'name': 'Juneau', 'pop2000': 30711, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC5E0>}
# {'objectid': 3122, 'name': 'Kodiak Island', 'pop2000': 13913, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC580>}
# {'objectid': 3123, 'name': 'Sitka', 'pop2000': 8835, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC520>}
# {'objectid': 3124, 'name': 'Wrangell-Petersburg', 'pop2000': 6684, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC3A0>}
# {'objectid': 3125, 'name': 'Ketchikan Gateway', 'pop2000': 14070, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC2B0>}
# {'objectid': 3126, 'name': 'Prince of Wales-Outer Ketchikan', 'pop2000': 6146, 'shape': <attgeo.Polygon object at 0x000001ACD6BBC220>}
# {'objectid': 3127, 'name': 'Aleutians East', 'pop2000': 2697, 'shape': <attgeo.Polygon object at 0x000001ACD6BBCB50>}
# {'objectid': 3128, 'name': 'Aleutians West', 'pop2000': 5465, 'shape': <attgeo.Polygon object at 0x000001ACD6BBCBB0>}
# {'objectid': 3129, 'name': 'Kalawao', 'pop2000': 147, 'shape': <attgeo.Polygon object at 0x000001ACD6BBCC10>}
# {'objectid': 3130, 'name': 'Kauai', 'pop2000': 58463, 'shape': <attgeo.Polygon object at 0x000001ACD6BBCD90>}
# {'objectid': 3131, 'name': 'Honolulu', 'pop2000': 876156, 'shape': <attgeo.Polygon object at 0x000001ACD6BBCDF0>}
# {'objectid': 3132, 'name': 'Maui', 'pop2000': 128094, 'shape': <attgeo.Polygon object at 0x000001ACD6BBCE50>}
# {'objectid': 3133, 'name': 'Hawaii', 'pop2000': 148677, 'shape': <attgeo.Polygon object at 0x000001ACD4C0BC70>}
# {'objectid': 3134, 'name': 'Pittsylvania', 'pop2000': 61745, 'shape': <attgeo.Polygon object at 0x000001ACD6B68310>}
# {'objectid': 3135, 'name': 'Danville', 'pop2000': 48411, 'shape': <attgeo.Polygon object at 0x000001ACD6B68940>}
# {'objectid': 3136, 'name': 'Valdez-Cordova', 'pop2000': 10195, 'shape': <attgeo.Polygon object at 0x000001ACD6B683A0>}
# {'objectid': 3137, 'name': 'Yakutat', 'pop2000': 808, 'shape': <attgeo.Polygon object at 0x000001ACD6B68640>}
# {'objectid': 3138, 'name': 'Skagway-Hoonah-Angoon', 'pop2000': 3436, 'shape': <attgeo.Polygon object at 0x000001ACD6B68D00>}
# {'objectid': 3139, 'name': 'Yukon-Koyukuk', 'pop2000': 6551, 'shape': <attgeo.Polygon object at 0x000001ACD6B68460>}
# {'objectid': 3140, 'name': 'Southeast Fairbanks', 'pop2000': 6174, 'shape': <attgeo.Polygon object at 0x000001ACD6BBCF10>}
# {'objectid': 3141, 'name': 'Denali', 'pop2000': 1893, 'shape': <attgeo.Polygon object at 0x000001ACD6BBCD60>}

# %%
from attgeo import Mapper
from datetime import datetime
from itertools import islice
from json import dumps

url = "https://sampleserver6.arcgisonline.com/arcgis/rest/services/SpatioTemporalAggregation/RainfallTimeSeriesDataIllinois/MapServer/7"

class Rain:
    objectid: int
    site_no: str
    date_time: datetime
    rainfall_inch: float

mapper = Mapper(url, Rain)

for rain in islice(mapper.read(), 123):
    print(rain.__dict__)
# Out:
# {'objectid': 1, 'site_no': '220739159373001', 'date_time': datetime.datetime(2011, 12, 31, 21, 15), 'rainfall_inch': 0.01}
# {'objectid': 2, 'site_no': '200518155405801', 'date_time': datetime.datetime(2011, 12, 31, 21, 30), 'rainfall_inch': 0.01}
# {'objectid': 3, 'site_no': '194117155174801', 'date_time': datetime.datetime(2011, 12, 31, 21, 30), 'rainfall_inch': 0.01}
# {'objectid': 4, 'site_no': '220927159355001', 'date_time': datetime.datetime(2011, 12, 31, 22, 0), 'rainfall_inch': 0.01}
# {'objectid': 5, 'site_no': '200518155405801', 'date_time': datetime.datetime(2011, 12, 31, 22, 15), 'rainfall_inch': 0.01}
# {'objectid': 6, 'site_no': '200518155405801', 'date_time': datetime.datetime(2011, 12, 31, 23, 0), 'rainfall_inch': 0.01}
# {'objectid': 7, 'site_no': '220523159341201', 'date_time': datetime.datetime(2011, 12, 31, 23, 45), 'rainfall_inch': 0.01}
# {'objectid': 8, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 0, 0), 'rainfall_inch': 0.03}
# {'objectid': 9, 'site_no': '423900090172100', 'date_time': datetime.datetime(2012, 1, 1, 0, 7), 'rainfall_inch': 0.009}
# {'objectid': 10, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 0, 15), 'rainfall_inch': 0.01}
# {'objectid': 11, 'site_no': '131729144393766', 'date_time': datetime.datetime(2012, 1, 1, 0, 30), 'rainfall_inch': 0.01}
# {'objectid': 12, 'site_no': '400641088152501', 'date_time': datetime.datetime(2012, 1, 1, 0, 40), 'rainfall_inch': 0.01}
# {'objectid': 13, 'site_no': '422834088255800', 'date_time': datetime.datetime(2012, 1, 1, 1, 5), 'rainfall_inch': 0.01}
# {'objectid': 14, 'site_no': '422834088255800', 'date_time': datetime.datetime(2012, 1, 1, 1, 25), 'rainfall_inch': 0.01}
# {'objectid': 15, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 1, 30), 'rainfall_inch': 0.01}
# {'objectid': 16, 'site_no': '415801088095700', 'date_time': datetime.datetime(2012, 1, 1, 1, 30), 'rainfall_inch': 0.01}
# {'objectid': 17, 'site_no': '415801088095700', 'date_time': datetime.datetime(2012, 1, 1, 1, 50), 'rainfall_inch': 0.01}
# {'objectid': 18, 'site_no': '420453088043200', 'date_time': datetime.datetime(2012, 1, 1, 2, 0), 'rainfall_inch': 0.01}
# {'objectid': 19, 'site_no': '422834088255800', 'date_time': datetime.datetime(2012, 1, 1, 2, 5), 'rainfall_inch': 0.02}
# {'objectid': 20, 'site_no': '420453088043200', 'date_time': datetime.datetime(2012, 1, 1, 2, 15), 'rainfall_inch': 0.01}
# {'objectid': 21, 'site_no': '422834088255800', 'date_time': datetime.datetime(2012, 1, 1, 2, 15), 'rainfall_inch': 0.01}
# {'objectid': 22, 'site_no': '415801088095700', 'date_time': datetime.datetime(2012, 1, 1, 2, 15), 'rainfall_inch': 0.01}
# {'objectid': 23, 'site_no': '420453088043200', 'date_time': datetime.datetime(2012, 1, 1, 2, 30), 'rainfall_inch': 0.01}
# {'objectid': 24, 'site_no': '400610088122201', 'date_time': datetime.datetime(2012, 1, 1, 2, 30), 'rainfall_inch': 0.01}
# {'objectid': 25, 'site_no': '415801088095700', 'date_time': datetime.datetime(2012, 1, 1, 2, 30), 'rainfall_inch': 0.01}
# {'objectid': 26, 'site_no': '350557083325845', 'date_time': datetime.datetime(2012, 1, 1, 2, 45), 'rainfall_inch': 0.03}
# {'objectid': 27, 'site_no': '400610088122201', 'date_time': datetime.datetime(2012, 1, 1, 2, 45), 'rainfall_inch': 0.01}
# {'objectid': 28, 'site_no': '400641088152501', 'date_time': datetime.datetime(2012, 1, 1, 2, 50), 'rainfall_inch': 0.01}
# {'objectid': 29, 'site_no': '415801088095700', 'date_time': datetime.datetime(2012, 1, 1, 2, 55), 'rainfall_inch': 0.01}
# {'objectid': 30, 'site_no': '212855157504501', 'date_time': datetime.datetime(2012, 1, 1, 3, 0), 'rainfall_inch': 0.04}
# {'objectid': 31, 'site_no': '422834088255800', 'date_time': datetime.datetime(2012, 1, 1, 3, 5), 'rainfall_inch': 0.01}
# {'objectid': 32, 'site_no': '422834088255800', 'date_time': datetime.datetime(2012, 1, 1, 3, 10), 'rainfall_inch': 0.01}
# {'objectid': 33, 'site_no': '213237157530701', 'date_time': datetime.datetime(2012, 1, 1, 3, 15), 'rainfall_inch': 0.05}
# {'objectid': 34, 'site_no': '213215157552800', 'date_time': datetime.datetime(2012, 1, 1, 3, 15), 'rainfall_inch': 0.01}
# {'objectid': 35, 'site_no': '415801088095700', 'date_time': datetime.datetime(2012, 1, 1, 3, 15), 'rainfall_inch': 0.01}
# {'objectid': 36, 'site_no': '412354087370001', 'date_time': datetime.datetime(2012, 1, 1, 3, 15), 'rainfall_inch': 0.01}
# {'objectid': 37, 'site_no': '212428157511201', 'date_time': datetime.datetime(2012, 1, 1, 3, 29), 'rainfall_inch': 0.01}
# {'objectid': 38, 'site_no': '212359157502601', 'date_time': datetime.datetime(2012, 1, 1, 3, 30), 'rainfall_inch': 0.06}
# {'objectid': 39, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 3, 30), 'rainfall_inch': 0.01}
# {'objectid': 40, 'site_no': '213215157552800', 'date_time': datetime.datetime(2012, 1, 1, 3, 30), 'rainfall_inch': 0.01}
# {'objectid': 41, 'site_no': '400610088122201', 'date_time': datetime.datetime(2012, 1, 1, 3, 40), 'rainfall_inch': 0.01}
# {'objectid': 42, 'site_no': '212428157511201', 'date_time': datetime.datetime(2012, 1, 1, 3, 43), 'rainfall_inch': 0.01}
# {'objectid': 43, 'site_no': '420453088043200', 'date_time': datetime.datetime(2012, 1, 1, 3, 45), 'rainfall_inch': 0.01}
# {'objectid': 44, 'site_no': '200518155405801', 'date_time': datetime.datetime(2012, 1, 1, 3, 45), 'rainfall_inch': 0.01}
# {'objectid': 45, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 3, 45), 'rainfall_inch': 0.01}
# {'objectid': 46, 'site_no': '213215157552800', 'date_time': datetime.datetime(2012, 1, 1, 3, 45), 'rainfall_inch': 0.02}
# {'objectid': 47, 'site_no': '415801088095700', 'date_time': datetime.datetime(2012, 1, 1, 3, 45), 'rainfall_inch': 0.01}
# {'objectid': 48, 'site_no': '412354087370001', 'date_time': datetime.datetime(2012, 1, 1, 3, 45), 'rainfall_inch': 0.01}
# {'objectid': 49, 'site_no': '212359157502601', 'date_time': datetime.datetime(2012, 1, 1, 4, 0), 'rainfall_inch': 0.01}
# {'objectid': 50, 'site_no': '412657087372001', 'date_time': datetime.datetime(2012, 1, 1, 4, 0), 'rainfall_inch': 0.04}
# {'objectid': 51, 'site_no': '413113087342201', 'date_time': datetime.datetime(2012, 1, 1, 4, 0), 'rainfall_inch': 0.04}
# {'objectid': 52, 'site_no': '213215157552800', 'date_time': datetime.datetime(2012, 1, 1, 4, 15), 'rainfall_inch': 0.01}
# {'objectid': 53, 'site_no': '350557083325845', 'date_time': datetime.datetime(2012, 1, 1, 4, 30), 'rainfall_inch': 0.01}
# {'objectid': 54, 'site_no': '200518155405801', 'date_time': datetime.datetime(2012, 1, 1, 4, 30), 'rainfall_inch': 0.01}
# {'objectid': 55, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 4, 30), 'rainfall_inch': 0.01}
# {'objectid': 56, 'site_no': '212855157504501', 'date_time': datetime.datetime(2012, 1, 1, 4, 30), 'rainfall_inch': 0.01}
# {'objectid': 57, 'site_no': '350557083325845', 'date_time': datetime.datetime(2012, 1, 1, 4, 45), 'rainfall_inch': 0.01}
# {'objectid': 58, 'site_no': '364109081585901', 'date_time': datetime.datetime(2012, 1, 1, 4, 45), 'rainfall_inch': 0.01}
# {'objectid': 59, 'site_no': '213237157530701', 'date_time': datetime.datetime(2012, 1, 1, 4, 45), 'rainfall_inch': 0.01}
# {'objectid': 60, 'site_no': '213215157552800', 'date_time': datetime.datetime(2012, 1, 1, 4, 45), 'rainfall_inch': 0.01}
# {'objectid': 61, 'site_no': '212855157504501', 'date_time': datetime.datetime(2012, 1, 1, 4, 45), 'rainfall_inch': 0.01}
# {'objectid': 62, 'site_no': '350557083325845', 'date_time': datetime.datetime(2012, 1, 1, 5, 0), 'rainfall_inch': 0.01}
# {'objectid': 63, 'site_no': '391056122420801', 'date_time': datetime.datetime(2012, 1, 1, 5, 0), 'rainfall_inch': 0.01}
# {'objectid': 64, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 5, 0), 'rainfall_inch': 0.02}
# {'objectid': 65, 'site_no': '213237157530701', 'date_time': datetime.datetime(2012, 1, 1, 5, 0), 'rainfall_inch': 0.01}
# {'objectid': 66, 'site_no': '213215157552800', 'date_time': datetime.datetime(2012, 1, 1, 5, 0), 'rainfall_inch': 0.04}
# {'objectid': 67, 'site_no': '212855157504501', 'date_time': datetime.datetime(2012, 1, 1, 5, 0), 'rainfall_inch': 0.01}
# {'objectid': 68, 'site_no': '200518155405801', 'date_time': datetime.datetime(2012, 1, 1, 5, 15), 'rainfall_inch': 0.01}
# {'objectid': 69, 'site_no': '213237157530701', 'date_time': datetime.datetime(2012, 1, 1, 5, 15), 'rainfall_inch': 0.01}
# {'objectid': 70, 'site_no': '213215157552800', 'date_time': datetime.datetime(2012, 1, 1, 5, 15), 'rainfall_inch': 0.03}
# {'objectid': 71, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 5, 30), 'rainfall_inch': 0.01}
# {'objectid': 72, 'site_no': '212359157502601', 'date_time': datetime.datetime(2012, 1, 1, 5, 45), 'rainfall_inch': 0.01}
# {'objectid': 73, 'site_no': '200518155405801', 'date_time': datetime.datetime(2012, 1, 1, 5, 45), 'rainfall_inch': 0.01}
# {'objectid': 74, 'site_no': '213237157530701', 'date_time': datetime.datetime(2012, 1, 1, 5, 45), 'rainfall_inch': 0.03}
# {'objectid': 75, 'site_no': '212855157504501', 'date_time': datetime.datetime(2012, 1, 1, 5, 45), 'rainfall_inch': 0.1}
# {'objectid': 76, 'site_no': '370733081332901', 'date_time': datetime.datetime(2012, 1, 1, 6, 0), 'rainfall_inch': 0.01}
# {'objectid': 77, 'site_no': '394050079180901', 'date_time': datetime.datetime(2012, 1, 1, 6, 0), 'rainfall_inch': 0.02}
# {'objectid': 78, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 6, 0), 'rainfall_inch': 0.02}
# {'objectid': 79, 'site_no': '213215157552800', 'date_time': datetime.datetime(2012, 1, 1, 6, 0), 'rainfall_inch': 0.01}
# {'objectid': 80, 'site_no': '212855157504501', 'date_time': datetime.datetime(2012, 1, 1, 6, 0), 'rainfall_inch': 0.05}
# {'objectid': 81, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 6, 15), 'rainfall_inch': 0.01}
# {'objectid': 82, 'site_no': '213237157530701', 'date_time': datetime.datetime(2012, 1, 1, 6, 15), 'rainfall_inch': 0.02}
# {'objectid': 83, 'site_no': '213215157552800', 'date_time': datetime.datetime(2012, 1, 1, 6, 15), 'rainfall_inch': 0.02}
# {'objectid': 84, 'site_no': '212855157504501', 'date_time': datetime.datetime(2012, 1, 1, 6, 15), 'rainfall_inch': 0.03}
# {'objectid': 85, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 6, 30), 'rainfall_inch': 0.02}
# {'objectid': 86, 'site_no': '371954082350601', 'date_time': datetime.datetime(2012, 1, 1, 6, 30), 'rainfall_inch': 0.06}
# {'objectid': 87, 'site_no': '213237157530701', 'date_time': datetime.datetime(2012, 1, 1, 6, 30), 'rainfall_inch': 0.03}
# {'objectid': 88, 'site_no': '213215157552800', 'date_time': datetime.datetime(2012, 1, 1, 6, 30), 'rainfall_inch': 0.03}
# {'objectid': 89, 'site_no': '212855157504501', 'date_time': datetime.datetime(2012, 1, 1, 6, 30), 'rainfall_inch': 0.03}
# {'objectid': 90, 'site_no': '415801088095700', 'date_time': datetime.datetime(2012, 1, 1, 6, 40), 'rainfall_inch': 0.01}
# {'objectid': 91, 'site_no': '200518155405801', 'date_time': datetime.datetime(2012, 1, 1, 6, 45), 'rainfall_inch': 0.01}
# {'objectid': 92, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 6, 45), 'rainfall_inch': 0.03}
# {'objectid': 93, 'site_no': '371954082350601', 'date_time': datetime.datetime(2012, 1, 1, 6, 45), 'rainfall_inch': 0.02}
# {'objectid': 94, 'site_no': '213237157530701', 'date_time': datetime.datetime(2012, 1, 1, 6, 45), 'rainfall_inch': 0.03}
# {'objectid': 95, 'site_no': '212855157504501', 'date_time': datetime.datetime(2012, 1, 1, 6, 45), 'rainfall_inch': 0.05}
# {'objectid': 96, 'site_no': '370546081500901', 'date_time': datetime.datetime(2012, 1, 1, 6, 45), 'rainfall_inch': 0.01}
# {'objectid': 97, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 7, 0), 'rainfall_inch': 0.03}
# {'objectid': 98, 'site_no': '213237157530701', 'date_time': datetime.datetime(2012, 1, 1, 7, 0), 'rainfall_inch': 0.01}
# {'objectid': 99, 'site_no': '133209144545301', 'date_time': datetime.datetime(2012, 1, 1, 7, 0), 'rainfall_inch': 0.01}
# {'objectid': 100, 'site_no': '213215157552800', 'date_time': datetime.datetime(2012, 1, 1, 7, 0), 'rainfall_inch': 0.02}
# {'objectid': 101, 'site_no': '212855157504501', 'date_time': datetime.datetime(2012, 1, 1, 7, 0), 'rainfall_inch': 0.02}
# {'objectid': 102, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 7, 15), 'rainfall_inch': 0.01}
# {'objectid': 103, 'site_no': '213237157530701', 'date_time': datetime.datetime(2012, 1, 1, 7, 15), 'rainfall_inch': 0.02}
# {'objectid': 104, 'site_no': '213215157552800', 'date_time': datetime.datetime(2012, 1, 1, 7, 15), 'rainfall_inch': 0.05}
# {'objectid': 105, 'site_no': '365433082033901', 'date_time': datetime.datetime(2012, 1, 1, 7, 30), 'rainfall_inch': 0.03}
# {'objectid': 106, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 7, 30), 'rainfall_inch': 0.01}
# {'objectid': 107, 'site_no': '371954082350601', 'date_time': datetime.datetime(2012, 1, 1, 7, 30), 'rainfall_inch': 0.01}
# {'objectid': 108, 'site_no': '213237157530701', 'date_time': datetime.datetime(2012, 1, 1, 7, 30), 'rainfall_inch': 0.01}
# {'objectid': 109, 'site_no': '213215157552800', 'date_time': datetime.datetime(2012, 1, 1, 7, 30), 'rainfall_inch': 0.02}
# {'objectid': 110, 'site_no': '352030083144745', 'date_time': datetime.datetime(2012, 1, 1, 7, 45), 'rainfall_inch': 0.01}
# {'objectid': 111, 'site_no': '365433082033901', 'date_time': datetime.datetime(2012, 1, 1, 7, 45), 'rainfall_inch': 0.02}
# {'objectid': 112, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 7, 45), 'rainfall_inch': 0.01}
# {'objectid': 113, 'site_no': '370546081500901', 'date_time': datetime.datetime(2012, 1, 1, 7, 45), 'rainfall_inch': 0.08}
# {'objectid': 114, 'site_no': '370733081332901', 'date_time': datetime.datetime(2012, 1, 1, 8, 0), 'rainfall_inch': 0.06}
# {'objectid': 115, 'site_no': '350557083325845', 'date_time': datetime.datetime(2012, 1, 1, 8, 0), 'rainfall_inch': 0.06}
# {'objectid': 116, 'site_no': '364109081585901', 'date_time': datetime.datetime(2012, 1, 1, 8, 0), 'rainfall_inch': 0.03}
# {'objectid': 117, 'site_no': '352030083144745', 'date_time': datetime.datetime(2012, 1, 1, 8, 0), 'rainfall_inch': 0.03}
# {'objectid': 118, 'site_no': '213335157540601', 'date_time': datetime.datetime(2012, 1, 1, 8, 0), 'rainfall_inch': 0.04}
# {'objectid': 119, 'site_no': '213237157530701', 'date_time': datetime.datetime(2012, 1, 1, 8, 0), 'rainfall_inch': 0.01}
# {'objectid': 120, 'site_no': '365314081460301', 'date_time': datetime.datetime(2012, 1, 1, 8, 0), 'rainfall_inch': 0.04}
# {'objectid': 121, 'site_no': '370546081500901', 'date_time': datetime.datetime(2012, 1, 1, 8, 0), 'rainfall_inch': 0.02}
# {'objectid': 122, 'site_no': '370733081332901', 'date_time': datetime.datetime(2012, 1, 1, 8, 15), 'rainfall_inch': 0.01}
# {'objectid': 123, 'site_no': '350557083325845', 'date_time': datetime.datetime(2012, 1, 1, 8, 15), 'rainfall_inch': 0.04}

# %%
from attgeo import Mapper, Point
from json import dumps

url = "https://sampleserver6.arcgisonline.com/arcgis/rest/services/RedlandsEmergencyVehicles/FeatureServer/0"

class Ambulance:
    objectid: int
    unitname: str
    status: int
    type: int
    callnumber: str
    speed: float
    shape: Point

mapper = Mapper(url, Ambulance)

ambulance = Ambulance()
ambulance.unitname = "Test 1"
ambulance.status = 0
ambulance.type = 1
ambulance.shape = Point()
ambulance.shape.x, ambulance.shape.y = -120, 50

mapper.apply_edits([ambulance])
# Out:
# [{'attributes': {'unitname': 'Test 1', 'status': 0, 'type': 1}, 'geometry': {'x': -120, 'y': 50}}]

# %%
from attgeo import Mapper, Point

url = "https://sampleserver6.arcgisonline.com/arcgis/rest/services/RedlandsEmergencyVehicles/FeatureServer/0"

class Ambulance:
    objectid: int
    unitname: str
    status: int
    type: int
    callnumber: str
    speed: float
    shape: Point

mapper = Mapper(url, Ambulance)

ambulance = Ambulance()
ambulance.unitname = "Test 1"
ambulance.status = 0
ambulance.type = 1
ambulance.shape = Point()
ambulance.shape.x, ambulance.shape.y = -120, 50

#mapper.apply_edits()

for ambulance in mapper.read():
    print(ambulance.__dict__)
# Out:
# {'objectid': 416044, 'unitname': 'Symons', 'status': 0, 'type': 0, 'callnumber': 'B4312432A3412', 'speed': 25.0, 'shape': <attgeo.Point object at 0x000001ACD6AE8850>}
# {'objectid': 416047, 'unitname': 'American Medical', 'status': 0, 'type': 1, 'callnumber': 'A1234B04289B', 'speed': 25.0, 'shape': <attgeo.Point object at 0x000001ACD4C05E50>}
# {'objectid': 416046, 'unitname': 'American Medical', 'status': 0, 'type': 1, 'callnumber': 'A1234B04289B', 'speed': 25.0, 'shape': <attgeo.Point object at 0x000001ACD4C05220>}
# {'objectid': 416043, 'unitname': 'Symons', 'status': 0, 'type': 1, 'callnumber': 'A5491342B12438', 'speed': 25.0, 'shape': <attgeo.Point object at 0x000001ACD4C05D90>}
# {'objectid': 416045, 'unitname': 'American Medical', 'status': 0, 'type': 1, 'callnumber': 'A94205B12258', 'speed': 25.0, 'shape': <attgeo.Point object at 0x000001ACD6AD7580>}
# {'objectid': 416042, 'unitname': 'Desert', 'status': 0, 'type': 1, 'callnumber': 'A5423C523454', 'speed': 25.0, 'shape': <attgeo.Point object at 0x000001ACD6BBC220>}
